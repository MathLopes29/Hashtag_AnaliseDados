# %% [markdown]
# # Informações

# %%
'''
  @author Grupo 5 - PUC Minas Gerais

  O conjunto de dados Gapminder é uma coleção rica de indicadores socioeconômicos e de
  saúde de diversos países ao redor do mundo, ao longo de várias décadas. Esse dataset foi
  desenvolvido a partir do trabalho da Fundação Gapminder, uma organização sem fins
  lucrativos criada pelo médico e estatístico sueco Hans Rosling, com o objetivo de
  promover uma visão baseada em dados sobre o desenvolvimento global.
  O dataset apresenta dados como:
  • Expectativa de vida (lifeExp)
  • Produto Interno Bruto per capita (gdpPercap)
  • População total (pop)
  • Ano de referência (year)
  • Continente (continent)
  • País (country)

  Essas informações são coletadas em intervalos de cinco anos, desde 1952 até 2007,
  abrangendo mais de 140 países.
'''
# Out:
# '\n  @author Grupo 5 - PUC Minas Gerais\n\n  O conjunto de dados Gapminder é uma coleção rica de indicadores socioeconômicos e de\n  saúde de diversos países ao redor do mundo, ao longo de várias décadas. Esse dataset foi\n  desenvolvido a partir do trabalho da Fundação Gapminder, uma organização sem fins\n  lucrativos criada pelo médico e estatístico sueco Hans Rosling, com o objetivo de\n  promover uma visão baseada em dados sobre o desenvolvimento global.\n  O dataset apresenta dados como:\n  • Expectativa de vida (lifeExp)\n  • Produto Interno Bruto per capita (gdpPercap)\n  • População total (pop)\n  • Ano de referência (year)\n  • Continente (continent)\n  • País (country)\n\n  Essas informações são coletadas em intervalos de cinco anos, desde 1952 até 2007,\n  abrangendo mais de 140 países.\n'

# %% [markdown]
# # Importação das Bibliotecas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import locale

locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
# Out:
# 'en_US.UTF-8'

# %%
df_original = pd.read_csv('C:\\Users\\negri\\OneDrive\\Documentos\\GitHub\\Hashtag_AnaliseDados\\Python\\Cursos\\PUC Ciência de Dados\\Projetos\\Python para Ciência de Dados\\gapminder_full.csv', encoding='utf-8')
display(df_original.head(10))
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# 5  Afghanistan  1977  14880372.0      Asia   38.438  786.113360
# 6  Afghanistan  1982  12881816.0      Asia   39.854  978.011439
# 7  Afghanistan  1987  13867957.0      Asia   40.822  852.395945
# 8  Afghanistan  1992  16317921.0      Asia   41.674  649.341395
# 9  Afghanistan  1997  22227415.0      Asia   41.763  635.341351

# %%
df_tratado = df_original.copy()
df_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1736 non-null   object
#  1   year       1736 non-null   int64
#  2   pop        1736 non-null   float64
#  3   continent  1736 non-null   object
#  4   lifeExp    1736 non-null   float64
#  5   gdpPercap  1736 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 81.5+ KB

# %%
df_tratado = df_tratado.rename(columns={'country':'País','year':'Ano', 'pop':'População total', 'continent':'Continente', 'lifeExp':'Expectativa de vida', 'gdpPercap':'Produto Interno Bruto per capita'})

# %%
df_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   País                              1736 non-null   object
#  1   Ano                               1736 non-null   int64
#  2   População total                   1736 non-null   float64
#  3   Continente                        1736 non-null   object
#  4   Expectativa de vida               1736 non-null   float64
#  5   Produto Interno Bruto per capita  1736 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 81.5+ KB

# %% [markdown]
# # Análise Inicial

# %%
df_tratado.describe()
# Out:
#                Ano  População total  Expectativa de vida  \
# count  1736.000000     1.736000e+03          1736.000000
# mean   1979.669931     3.156800e+07            59.511979
# std      17.296364     1.172888e+08            12.956028
# min    1952.000000     6.001100e+04            23.599000
# 25%    1967.000000     2.818694e+06            48.245000
# 50%    1982.000000     7.150606e+06            60.808000
# 75%    1997.000000     1.977102e+07            70.945000
# max    2007.000000     1.318683e+09            82.603000
#
#        Produto Interno Bruto per capita
# count                       1736.000000
# mean                        7240.155986
# std                         9839.873695
# min                          241.165876
# 25%                         1202.060309
# 50%                         3534.772106
# 75%                         9380.254270
# max                       113523.132900

# %%
df_tratado['País'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo Dem. Rep.', 'Congo Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea Dem. Rep.',
# ...

# %%
df_tratado['País'].value_counts()
# Out:
# País
# France                19
# Bolivia               17
# Guinea                17
# Ecuador               15
# China                 15
#                       ..
# Vietnam               12
# West Bank and Gaza    12
# Yemen Rep.            12
# Zambia                12
# Zimbabwe              12
# Name: count, Length: 142, dtype: int64

# %% [markdown]
# # TESTES

# %%
#df_tratado['Condição'] = np.where(df_tratado['Expectativa de vida'] > 70, 'Alta', 'Baixa')

# %%
#df_tratado.loc[df_tratado['Expectativa de vida'] >= 30, 'Condição'] = 'Média'
#df_tratado.loc[df_tratado['Expectativa de vida'] >= 70, 'Condição'] = 'Alta'
#df_tratado.loc[df_tratado['Expectativa de vida'] < 30, 'Condição'] = 'Baixa'

# %%
# Define conditions
conditions = [
    (df_tratado['Expectativa de vida'] < 30),
    ((df_tratado['Expectativa de vida'] >= 30) & (df_tratado['Expectativa de vida'] <= 70)),
    (df_tratado['Expectativa de vida'] > 70)
]

# Define corresponding values
values = ['Baixa', 'Média', 'Alta']

# Create 'Grade' column; default is 'F' if no conditions are met
df_tratado['Condição'] = np.select(conditions, values, default='F')

# %%
#df_tratado.loc[df_tratado['Condição']=='Alta']

# %%
#filter = df_tratado.duplicated()
#df_tratado[filter]

# %%
df_tratado.duplicated().sum()
# Out:
# np.int64(32)

# %%
'''
filter = df_tratado['País'] == 'Guinea'
df_tratado[filter]
'''
# Out:
# "\nfilter = df_tratado['País'] == 'Guinea'\ndf_tratado[filter]\n"

# %%
df_tratado.drop_duplicates(inplace=True)

# %%
df_tratado.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1704 entries, 0 to 1735
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   País                              1704 non-null   object
#  1   Ano                               1704 non-null   int64
#  2   População total                   1704 non-null   float64
#  3   Continente                        1704 non-null   object
#  4   Expectativa de vida               1704 non-null   float64
#  5   Produto Interno Bruto per capita  1704 non-null   float64
#  6   Condição                          1704 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 106.5+ KB

# %%
df_tratado.isnull().sum()
# Out:
# País                                0
# Ano                                 0
# População total                     0
# Continente                          0
# Expectativa de vida                 0
# Produto Interno Bruto per capita    0
# Condição                            0
# dtype: int64

# %%
df_tratado.isna().sum()
# Out:
# País                                0
# Ano                                 0
# População total                     0
# Continente                          0
# Expectativa de vida                 0
# Produto Interno Bruto per capita    0
# Condição                            0
# dtype: int64

# %%
df_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1704 entries, 0 to 1735
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   País                              1704 non-null   object
#  1   Ano                               1704 non-null   int64
#  2   População total                   1704 non-null   float64
#  3   Continente                        1704 non-null   object
#  4   Expectativa de vida               1704 non-null   float64
#  5   Produto Interno Bruto per capita  1704 non-null   float64
#  6   Condição                          1704 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 106.5+ KB

# %%
df_tratado.corr(numeric_only=True)
# Out:
#                                        Ano  População total  \
# Ano                               1.000000         0.082308
# População total                   0.082308         1.000000
# Expectativa de vida               0.435611         0.064955
# Produto Interno Bruto per capita  0.227318        -0.025600
#
#                                   Expectativa de vida  \
# Ano                                          0.435611
# População total                              0.064955
# Expectativa de vida                          1.000000
# Produto Interno Bruto per capita             0.583706
#
#                                   Produto Interno Bruto per capita
# Ano                                                       0.227318
# População total                                          -0.025600
# Expectativa de vida                                       0.583706
# Produto Interno Bruto per capita                          1.000000

# %%
sns.heatmap(df_tratado.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # GRÁFICOS & VISUAIS

# %%
filtro = df_tratado['País'] == 'Brazil'

plt.plot(df_tratado.loc[filtro,'Ano'], df_tratado.loc[filtro, 'Expectativa de vida'], marker='o', linestyle='--', color='green')
plt.title('Evolução da Expectativa de Vida - Brasil')
plt.xlabel('Anos')
plt.ylabel('Expectativa de Vida')
plt.xticks(df_tratado.loc[filtro,'Ano'].unique(), rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
from tkinter import font
from cycler import cycler

continente = df_tratado['Continente'].unique()
expectativa_media = df_tratado['Expectativa de vida'].groupby(df_tratado['Continente']).mean()


#cores = plt.get_cmap('Set3').colors
#ciclos_cores = cycler(color=cores)
#plt.rc('axes', prop_cycle = ciclos_cores)

plt.bar(continente,expectativa_media)
barras = plt.bar(continente, expectativa_media, color='SkyBlue', align='center', edgecolor='black', linewidth=1, alpha=0.5)
plt.bar_label(barras, labels=[f'{r:.2f} Anos' for r in expectativa_media], padding=3, fontsize=7, color='black', fontweight='bold')
plt.xlabel("Continente", fontsize=8, style='italic')
plt.ylabel("Expectativa de Vida", fontsize=8, style='italic')
plt.xticks(continente, rotation=45, fontsize=7)
plt.yticks(fontsize=7)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
