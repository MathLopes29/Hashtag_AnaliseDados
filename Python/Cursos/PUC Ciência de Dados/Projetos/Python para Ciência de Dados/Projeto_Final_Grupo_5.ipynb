# %% [markdown]
# # Informações do Grupo e do Projeto
#
# Descrição das principais informações desse notebook

# %%
'''
  @group: Grupo 5 - PUC Minas Gerais
  @authors
    - Matheus Lopes Lourenço (1666264@sga.pucminas.br)
    - Alef Cleto Almeida (1668545@sga.pucminas.br)
    - Leandro Oliveira (1664908@sga.pucminas.br)
    - Thiago Alves (1665652@sga.pucminas.br)
  @version final

  @description:
    O conjunto de dados Gapminder é uma coleção rica de indicadores socioeconômicos e de
    saúde de diversos países ao redor do mundo, ao longo de várias décadas. Esse dataset foi
    desenvolvido a partir do trabalho da Fundação Gapminder, uma organização sem fins
    lucrativos criada pelo médico e estatístico sueco Hans Rosling, com o objetivo de
    promover uma visão baseada em dados sobre o desenvolvimento global.
    O dataset apresenta dados como:

    • Expectativa de vida (lifeExp)
    • Produto Interno Bruto per capita (gdpPercap)
    • População total (pop)
    • Ano de referência (year)
    • Continente (continent)
    • País (country)

    Essas informações são coletadas em intervalos de cinco anos, desde 1952 até 2007,
    abrangendo mais de 140 países.
'''
# Out:
# '\n  @group: Grupo 5 - PUC Minas Gerais\n  @authors\n    - Matheus Lopes Lourenço (1666264@sga.pucminas.br)\n    - Alef Cleto Almeida (1668545@sga.pucminas.br)\n    - Leandro Oliveira (1664908@sga.pucminas.br)\n    - Thiago Alves (1665652@sga.pucminas.br)\n  @version final\n\n  @description:\n    O conjunto de dados Gapminder é uma coleção rica de indicadores socioeconômicos e de\n    saúde de diversos países ao redor do mundo, ao longo de várias décadas. Esse dataset foi\n    desenvolvido a partir do trabalho da Fundação Gapminder, uma organização sem fins\n    lucrativos criada pelo médico e estatístico sueco Hans Rosling, com o objetivo de\n    promover uma visão baseada em dados sobre o desenvolvimento global.\n    O dataset apresenta dados como:\n\n    • Expectativa de vida (lifeExp)\n    • Produto Interno Bruto per capita (gdpPercap)\n    • População total (pop)\n    • Ano de referência (year)\n    • Continente (continent)\n    • País (country)\n\n    Essas informações são cole
# ...

# %% [markdown]
# # Importação das Bibliotecas
#
# Importação, Criação do DataFrame, Leitura Inicial e Visualização

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import locale

locale.setlocale(locale.LC_ALL, 'en_US.UTF-8')
# Out:
# 'en_US.UTF-8'

# %%
df_original = pd.read_csv('/content/gapminder_full.csv', encoding='utf-8')
display(df_original.head(10))
# Out:
#        country  year         pop continent  lifeExp   gdpPercap
# 0  Afghanistan  1952   8425333.0      Asia   28.801  779.445314
# 1  Afghanistan  1957   9240934.0      Asia   30.332  820.853030
# 2  Afghanistan  1962  10267083.0      Asia   31.997  853.100710
# 3  Afghanistan  1967  11537966.0      Asia   34.020  836.197138
# 4  Afghanistan  1972  13079460.0      Asia   36.088  739.981106
# 5  Afghanistan  1977  14880372.0      Asia   38.438  786.113360
# 6  Afghanistan  1982  12881816.0      Asia   39.854  978.011439
# 7  Afghanistan  1987  13867957.0      Asia   40.822  852.395945
# 8  Afghanistan  1992  16317921.0      Asia   41.674  649.341395
# 9  Afghanistan  1997  22227415.0      Asia   41.763  635.341351

# %%
df_tratado = df_original.copy()
df_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1736 non-null   object
#  1   year       1736 non-null   int64
#  2   pop        1736 non-null   float64
#  3   continent  1736 non-null   object
#  4   lifeExp    1736 non-null   float64
#  5   gdpPercap  1736 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 81.5+ KB

# %%
df_tratado = df_tratado.rename(columns={'country':'País','year':'Ano', 'pop':'População total', 'continent':'Continente', 'lifeExp':'Expectativa de vida', 'gdpPercap':'Produto Interno Bruto per capita'})

# %%
df_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   País                              1736 non-null   object
#  1   Ano                               1736 non-null   int64
#  2   População total                   1736 non-null   float64
#  3   Continente                        1736 non-null   object
#  4   Expectativa de vida               1736 non-null   float64
#  5   Produto Interno Bruto per capita  1736 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 81.5+ KB

# %% [markdown]
# # Análise Inicial
#
# Descrição do Dataframe e Visualização de algumas colunas

# %%
df_tratado.describe()
# Out:
#                Ano  População total  Expectativa de vida  \
# count  1736.000000     1.736000e+03          1736.000000
# mean   1979.669931     3.156800e+07            59.511979
# std      17.296364     1.172888e+08            12.956028
# min    1952.000000     6.001100e+04            23.599000
# 25%    1967.000000     2.818694e+06            48.245000
# 50%    1982.000000     7.150606e+06            60.808000
# 75%    1997.000000     1.977102e+07            70.945000
# max    2007.000000     1.318683e+09            82.603000
#
#        Produto Interno Bruto per capita
# count                       1736.000000
# mean                        7240.155986
# std                         9839.873695
# min                          241.165876
# 25%                         1202.060309
# 50%                         3534.772106
# 75%                         9380.254270
# max                       113523.132900

# %%
df_tratado['País'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo Dem. Rep.', 'Congo Rep.',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hong Kong China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea Dem. Rep.',
# ...

# %%
df_tratado['País'].value_counts()
# Out:
# País
# France                19
# Bolivia               17
# Guinea                17
# Ecuador               15
# China                 15
#                       ..
# Vietnam               12
# West Bank and Gaza    12
# Yemen Rep.            12
# Zambia                12
# Zimbabwe              12
# Name: count, Length: 142, dtype: int64

# %% [markdown]
# # Primeiras Tratativas
#
# 1ª Filtrando e criando condições no dataframe, 2ª Eliminação dos dados repetidos e informações "NULL" e 3ª Análise das correlações entre os valores númericos da base

# %%
#df_tratado['Condição'] = np.where(df_tratado['Expectativa de vida'] > 70, 'Alta', 'Baixa')

# %%
#df_tratado.loc[df_tratado['Expectativa de vida'] >= 30, 'Condição'] = 'Média'
#df_tratado.loc[df_tratado['Expectativa de vida'] >= 70, 'Condição'] = 'Alta'
#df_tratado.loc[df_tratado['Expectativa de vida'] < 30, 'Condição'] = 'Baixa'

# %%
# Define condições
conditions = [
    (df_tratado['Expectativa de vida'] < 35),
    ((df_tratado['Expectativa de vida'] >= 35) & (df_tratado['Expectativa de vida'] <= 65)),
    (df_tratado['Expectativa de vida'] > 65)
]

# Define valores correspondentes para cada condição
values = ['Baixa', 'Média', 'Alta']

# Aplica as condições para criar a nova coluna 'Condição'
df_tratado['Condição'] = np.select(conditions, values, default='F')

# %%
#df_tratado.loc[df_tratado['Condição']=='Alta']

# %%
#filter = df_tratado.duplicated()
#df_tratado[filter]

# %%
df_tratado.duplicated().sum()
# Out:
# np.int64(32)

# %%
#filter = df_tratado['País'] == 'Guinea'
#df_tratado[filter]

# %%
df_tratado.drop_duplicates(inplace=True)

# %%
df_tratado.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1704 entries, 0 to 1735
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   País                              1704 non-null   object
#  1   Ano                               1704 non-null   int64
#  2   População total                   1704 non-null   float64
#  3   Continente                        1704 non-null   object
#  4   Expectativa de vida               1704 non-null   float64
#  5   Produto Interno Bruto per capita  1704 non-null   float64
#  6   Condição                          1704 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 106.5+ KB

# %%
df_tratado.isnull().sum()
# Out:
# País                                0
# Ano                                 0
# População total                     0
# Continente                          0
# Expectativa de vida                 0
# Produto Interno Bruto per capita    0
# Condição                            0
# dtype: int64

# %%
df_tratado.isna().sum()
# Out:
# País                                0
# Ano                                 0
# População total                     0
# Continente                          0
# Expectativa de vida                 0
# Produto Interno Bruto per capita    0
# Condição                            0
# dtype: int64

# %%
df_tratado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1704 entries, 0 to 1735
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   País                              1704 non-null   object
#  1   Ano                               1704 non-null   int64
#  2   População total                   1704 non-null   float64
#  3   Continente                        1704 non-null   object
#  4   Expectativa de vida               1704 non-null   float64
#  5   Produto Interno Bruto per capita  1704 non-null   float64
#  6   Condição                          1704 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 106.5+ KB

# %%
df_tratado.corr(numeric_only=True)
# Out:
#                                        Ano  População total  \
# Ano                               1.000000         0.082308
# População total                   0.082308         1.000000
# Expectativa de vida               0.435611         0.064955
# Produto Interno Bruto per capita  0.227318        -0.025600
#
#                                   Expectativa de vida  \
# Ano                                          0.435611
# População total                              0.064955
# Expectativa de vida                          1.000000
# Produto Interno Bruto per capita             0.583706
#
#                                   Produto Interno Bruto per capita
# Ano                                                       0.227318
# População total                                          -0.025600
# Expectativa de vida                                       0.583706
# Produto Interno Bruto per capita                          1.000000

# %%
sns.heatmap(df_tratado.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(df_tratado, figsize=(16,16), hist_kwds={'bins':10, 'edgecolor': 'Black'});

# %% [markdown]
# # Análise de Teste de Data Frame

# %%
#df_tratado.groupby('País')['Expectativa de vida'].unique()
df_2002 = df_tratado[df_tratado['Ano'] == 2002].copy()
#df_brasil = df[df['country'] == 'Brazil'].copy()
#df_brasil.shape
#print(df_brasil)

#df_tratado['Continente'].value_counts()

#Criando dataframes para cada continente
df_americas = df_tratado[df_tratado['Continente']=='Americas'].copy()
df_asia = df_tratado[df_tratado['Continente'] =='Asia']
df_europe = df_tratado[df_tratado['Continente'] =='Europe'].copy()
df_africa = df_tratado[df_tratado['Continente'] =='Africa'].copy()

# %%
df_asia.head()
# Out:
#           País   Ano  População total Continente  Expectativa de vida  \
# 0  Afghanistan  1952        8425333.0       Asia               28.801
# 1  Afghanistan  1957        9240934.0       Asia               30.332
# 2  Afghanistan  1962       10267083.0       Asia               31.997
# 3  Afghanistan  1967       11537966.0       Asia               34.020
# 4  Afghanistan  1972       13079460.0       Asia               36.088
#
#    Produto Interno Bruto per capita Condição
# 0                        779.445314    Baixa
# 1                        820.853030    Baixa
# 2                        853.100710    Baixa
# 3                        836.197138    Baixa
# 4                        739.981106    Média

# %%
#Cria gráfico de linhas para visualizar a evolução da população total em cada continente ao longo dos anos
evolucao = df_tratado.groupby(['Ano', 'Continente'])['População total'].sum().unstack()

plt.figure(figsize=(12, 6))

for continent in evolucao.columns:
    plt.plot(evolucao.index, evolucao[continent], marker='o', linestyle='--', label=continent)

plt.title('Evolução da população por continente', fontsize=15, fontweight='bold')
plt.xlabel('Ano', fontsize=9, fontweight='bold')
plt.xticks(evolucao.index, rotation=45, fontsize=7)
plt.ylabel('População total', fontsize=9, fontweight='bold')
plt.yticks(fontsize=7)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Continente', fontsize=7, title_fontsize=8)
plt.tight_layout()
plt.show()

# %%
# Função para calcular os 10 maiores valores de um df
def top10(dataframe,col):
  maiores = dataframe.nlargest(10,col)
  continente = maiores['Continente'].value_counts()
  return display(maiores, continente)

# Função para calcular os 10 menores valores de um df
def bottom10(dataframe,col):
  menores = dataframe.nsmallest(10,col)
  continente = menores['Continente'].value_counts()
  return display(menores, continente)

# %%
print(f'Maiores e menores expectativas de vida em 2002:')
top10(df_2002,'Expectativa de vida')
bottom10(df_2002,'Expectativa de vida')
# Out:
# Maiores e menores expectativas de vida em 2002:
#                  País   Ano  População total Continente  Expectativa de vida  \
# 834             Japan  2002      127065841.0       Asia               82.000
# 702   Hong Kong China  2002        6762476.0       Asia               81.495
# 1518      Switzerland  2002        7361757.0     Europe               80.620
# 726           Iceland  2002         288030.0     Europe               80.500
# 70          Australia  2002       19546792.0    Oceania               80.370
# 810             Italy  2002       57926999.0     Europe               80.240
# 1506           Sweden  2002        8954175.0     Europe               80.040
# 1458            Spain  2002       40152517.0     Europe               79.780
# 259            Canada  2002       31902268.0   Americas               79.770
# 798            Israel  2002        6029529.0       Asia               79.696
#
#       Produto Interno Bruto per capita Condição
# ...

# %%
print(f'Maiores e menores valores de PIB per capita em 2002:')
top10(df_2002,'Produto Interno Bruto per capita')
bottom10(df_2002,'Produto Interno Bruto per capita')
# Out:
# Maiores e menores valores de PIB per capita em 2002:
#                País   Ano  População total Continente  Expectativa de vida  \
# 1182         Norway  2002        4535591.0     Europe               79.050
# 1650  United States  2002      287675526.0   Americas               77.310
# 1398      Singapore  2002        4197776.0       Asia               78.770
# 894          Kuwait  2002        2111561.0       Asia               76.904
# 1518    Switzerland  2002        7361757.0     Europe               80.620
# 786         Ireland  2002        3879155.0     Europe               77.783
# 1122    Netherlands  2002       16122830.0     Europe               78.530
# 259          Canada  2002       31902268.0   Americas               79.770
# 83          Austria  2002        8148312.0     Europe               78.980
# 430         Denmark  2002        5374693.0     Europe               77.180
#
#       Produto Interno Bruto per capita Condição
# ...

# %%
sns.boxplot(
    data=df_tratado,
    x="Continente",
    y="Expectativa de vida",
    palette="Set2"
)
plt.title("Distribuição da Expectativa de Vida por Continente")
plt.show()

# %% [markdown]
# # Gráficos e Análises do Dataframe
#
# Estudo em cima da base de Desenvolvimento  Humano  e  Econômico  Global

# %%
# Expectativa de Vida Média por Continente
from tkinter import font
from cycler import cycler

continente = df_tratado['Continente'].unique()
expectativa_media = df_tratado['Expectativa de vida'].groupby(df_tratado['Continente']).mean()


#cores = plt.get_cmap('Set3').colors
#ciclos_cores = cycler(color=cores)
#plt.rc('axes', prop_cycle = ciclos_cores)

plt.figure(figsize=(12, 6))
plt.bar(continente,expectativa_media)
plt.title('Expectativa de Vida Média por Continente', fontsize=10, fontweight='bold')
barras = plt.bar(continente, expectativa_media, color='SkyBlue', align='center', edgecolor='black', linewidth=1, alpha=0.5)
plt.bar_label(barras, labels=[f'{r:.2f} Anos' for r in expectativa_media], padding=3, fontsize=7, color='black', fontweight='bold')
plt.xlabel("Continente", fontsize=8, style='italic', labelpad=10, fontweight='bold')
plt.ylabel("Expectativa de Vida", fontsize=8, style='italic', fontweight='bold')
plt.xticks(continente, rotation=45, fontsize=7)
plt.yticks(fontsize=7)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Evolução da população por continente
evolucao = df_tratado.groupby(['Ano', 'Continente'])['População total'].sum().unstack()

plt.figure(figsize=(12, 6))

for continente in evolucao.columns:
    plt.plot(evolucao.index, evolucao[continente], marker='o', linestyle='--', label=continente)

plt.title('Evolução da população por continente', fontsize=15, fontweight='bold')
plt.xlabel('Ano', fontsize=9, fontweight='bold')
plt.xticks(evolucao.index, rotation=45, fontsize=7)
plt.ylabel('População total', fontsize=9, fontweight='bold')
plt.yticks(fontsize=7)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Continente', fontsize=7, title_fontsize=8)
plt.tight_layout()
plt.show()

# %%
# Função para criar dfs por ano
def df_por_ano(dataframe,ano):
  df_resultado = df_tratado[df_tratado['Ano']==ano].reset_index(drop=True)
  return df_resultado.copy()

# %%
# Verificando se pressuposto visual de correlação observado no continente asiático ocorre em todos os continentes
df_tratado_2002 = df_por_ano(df_tratado,2002)
sns.scatterplot(data=df_tratado_2002, x="Expectativa de vida", y="Produto Interno Bruto per capita",hue='Continente')
plt.title("Dispersão dos dados de expectativa de vida e PIB per capita - 2002")
# Out:
# Text(0.5, 1.0, 'Dispersão dos dados de expectativa de vida e PIB per capita - 2002')

# %%
# Evolução da expectativa de vida por país - O usuário pode escolher o país que deseja visualizar a evolução da expectativa de vida ao longo dos anos.
pais_escolhido = input("País que deseja visualizar a evolução da expectativa de vida: ")
lista_pais = ['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
       'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
       'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
       'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
       'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
       'Colombia', 'Comoros', 'Congo Dem. Rep.', 'Congo Rep.',
       'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Czech Republic',
       'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
       'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
       'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
       'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
       'Honduras', 'Hong Kong China', 'Hungary', 'Iceland', 'India',
       'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
       'Jamaica', 'Japan', 'Jordan', 'Kenya', 'Korea Dem. Rep.',
       'Korea Rep.', 'Kuwait', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
       'Madagascar', 'Malawi', 'Malaysia', 'Mali', 'Mauritania',
       'Mauritius', 'Mexico', 'Mongolia', 'Montenegro', 'Morocco',
       'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Netherlands',
       'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Norway', 'Oman',
       'Pakistan', 'Panama', 'Paraguay', 'Peru', 'Philippines', 'Poland',
       'Portugal', 'Puerto Rico', 'Reunion', 'Romania', 'Rwanda',
       'Sao Tome and Principe', 'Saudi Arabia', 'Senegal', 'Serbia',
       'Sierra Leone', 'Singapore', 'Slovak Republic', 'Slovenia',
       'Somalia', 'South Africa', 'Spain', 'Sri Lanka', 'Sudan',
       'Swaziland', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
       'Tanzania', 'Thailand', 'Togo', 'Trinidad and Tobago', 'Tunisia',
       'Turkey', 'Uganda', 'United Kingdom', 'United States', 'Uruguay',
       'Venezuela', 'Vietnam', 'West Bank and Gaza', 'Yemen Rep.',
       'Zambia', 'Zimbabwe']

if pais_escolhido not in lista_pais:
    print("País não encontrado.")
else:
    filtro = df_tratado['País'] == pais_escolhido

evolucao = df_tratado[filtro].groupby('Ano')['Expectativa de vida'].mean()

plt.figure(figsize=(12, 6))
plt.title(f'Evolução da Expectativa de Vida - {pais_escolhido}', fontsize=12, fontweight='bold')
plt.plot(
    evolucao.index,
    evolucao.values,
    marker='o',
    linestyle='--',
    color='darkblue'
)
plt.xlabel('Anos', fontsize=9, fontweight='bold')
plt.ylabel('Expectativa de Vida', fontsize=9, fontweight='bold')
plt.xticks(evolucao.index, rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# País que deseja visualizar a evolução da expectativa de vida: Italy

# %%
# Função que categoriza os países das Américas.
def categorizar_america(pais):
    match pais:
        # América do Sul
        case 'Argentina' | 'Bolivia' | 'Brazil' | 'Chile' | 'Colombia' | 'Ecuador' | 'Paraguay' | 'Peru' | 'Uruguay' | 'Venezuela':
            return 'América do Sul'

        # América do Norte
        case 'Canada' | 'United States' | 'Mexico':
            return 'América do Norte'

        # América Central / Caribe
        case 'Costa Rica' | 'Cuba' | 'Dominican Republic' | 'El Salvador' | 'Guatemala' | 'Haiti' | 'Honduras' | 'Jamaica' | 'Nicaragua' | 'Panama' | 'Puerto Rico' | 'Trinidad and Tobago':
            return 'América Central/Caribe'

        case _:
            return 'Outro continente'

df_tratado['Região América'] = df_tratado['País'].apply(categorizar_america)

# %%
# Visualização da Contagem de países por região das Américas
df_tratado['Região América'].value_counts()
# Out:
# Região América
# Outro continente          1404
# América Central/Caribe     144
# América do Sul             120
# América do Norte            36
# Name: count, dtype: int64

# %%
# Comparação do PIB per capita médio entre as regiões das Américas para um ano específico escolhido pelo usuário.
ano_escolhido = int(input("Digite o ano que deseja visualizar, entre 1952 e 2007, em intervalos de 5 anos: "))
if ano_escolhido in [1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002, 2007]:
    print("Ano válido")
else:
    print("Ano inválido. Por favor, escolha um ano entre 1952 e 2007, em intervalos de 5 anos.")

# Filtrar ano e remover outros continentes
filtro = (
    (df_tratado['Ano'] == ano_escolhido) &
    (df_tratado['Região América'] != 'Outro continente')
)

# Agrupar por região
pib_regiao = (
    df_tratado[filtro]
    .groupby('Região América')['Produto Interno Bruto per capita']
    .mean()
)

plt.figure(figsize=(12, 6))

barras = plt.bar(
    pib_regiao.index,
    pib_regiao.values,
    color='skyblue',
    edgecolor='black',
    linewidth=1,
    alpha=0.7
)

plt.bar_label(
    barras,
    labels=[f'$ {valor:.2f}' for valor in pib_regiao.values],
    padding=3,
    fontsize=8
)

plt.title(f' Média do PIB per capita das Américas - {ano_escolhido}', fontsize=12, fontweight='bold')
plt.xlabel('Região', fontsize=10, fontweight='bold')
plt.ylabel('PIB per capita', fontsize=10, fontweight='bold')
plt.xticks(rotation=20)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Digite o ano que deseja visualizar, entre 1952 e 2007, em intervalos de 5 anos: 1957
# Ano válido

# %%
# Comparação da evolução do PIB per capita ao longo do tempo para um conjunto de países escolhidos pelo usuário.
paises = input("Digite os países que deseja comparar, separados por virgula e o nome do país em inglês: ").split(',')
for pais in paises:
    paises = [pais.strip() for pais in paises]
else:
    print("Países válidos")

df_filtrado = df_tratado[df_tratado['País'].isin(paises)]

fig, ax = plt.subplots(figsize=(12, 8))

for pais in paises:
    dados_pais = df_filtrado[df_filtrado['País'] == pais]
    ax.plot(
        dados_pais['Ano'],
        dados_pais['Produto Interno Bruto per capita'],
        marker='o',
        label=pais
    )

ax.set_title('PIB per capita ao longo do tempo', fontsize=12, fontweight='bold')
ax.set_xlabel('Ano', fontsize=10, fontweight='bold', labelpad=10)
ax.set_ylabel('PIB per capita', fontsize=10, fontweight='bold', labelpad=10)
ax.legend()
ax.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# Digite os países que deseja comparar, separados por virgula e o nome do país em inglês: Brazil,Cuba,Argentina,Colombia,Argentina,Togo
# Países válidos

# %%
# Gráfico Adicional: Cria gráfico de linhas para visualizar a evolução do PIB per capita em cada continente ao longo dos anos
evolucao2 = df_tratado.groupby(['Ano', 'Continente'])['Produto Interno Bruto per capita'].sum().unstack()

plt.figure(figsize=(12, 6))

for continent in evolucao2.columns:
    plt.plot(evolucao2.index, evolucao2[continent], marker='o', linestyle='--', label=continent)

plt.title('Evolução do PIB per capita por continente', fontsize=15, fontweight='bold')
plt.xlabel('Ano', fontsize=9, fontweight='bold')
plt.xticks(evolucao2.index, rotation=45, fontsize=7)
plt.ylabel('Produto Interno Bruto per capita', fontsize=9, fontweight='bold')
plt.yticks(fontsize=7)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='Continente', fontsize=7, title_fontsize=8)
plt.tight_layout()
plt.show()

# %%
# Gráfico de pizza mostrando a distribuição percentual da população por continente para um ano específico escolhido pelo usuário.
from cycler import cycler

#cores = plt.get_cmap('Set3').colors
#ciclo_cores = cycler(color=cores)
#plt.rc('axes', prop_cycle=ciclo_cores)

ano_escolhido = int(input("Digite o ano que deseja visualizar, entre 1952 e 2007, em intervalos de 5 anos: "))
dados = df_tratado[df_tratado['Ano'] == ano_escolhido].groupby('Continente')['População total'].sum()
maior_continente = dados.idxmax()
destaque = [0.1 if continente == maior_continente else 0 for continente in dados.index]

plt.pie(
    dados,
    labels=dados.index,
    autopct='%1.1f%%',
    startangle=140,
    shadow=True,
    explode=destaque
)

plt.title(f'Distribuição da População por Continente - {ano_escolhido}', fontsize=10, fontweight='bold', pad=20)
plt.axis('equal')
plt.show()
# Out:
# Digite o ano que deseja visualizar, entre 1952 e 2007, em intervalos de 5 anos: 1992

# %%
# Gráfico de Pizza mostrando a distribuição de Países por Condições de Expectativa de Vida (Alta, Média, Baixa) para um ano específico escolhido pelo usuário.
from cycler import cycler

#cores = plt.get_cmap('Set3').colors
#ciclo_cores = cycler(color=cores)
#plt.rc('axes', prop_cycle=ciclo_cores)

ano_escolhido = int(input("Digite o ano que deseja visualizar, entre 1952 e 2007, em intervalos de 5 anos: "))
dados = df_tratado[df_tratado['Ano'] == ano_escolhido].groupby('Condição')['Condição'].count()
maior_continente = dados.idxmax()
destaque = [0.1 if continente == maior_continente else 0 for continente in dados.index]

plt.pie(
    dados,
    labels=dados.index,
    autopct='%1.1f%%',
    startangle=140,
    shadow=True,
    explode=destaque
)

plt.title(f'Distribuição por Condições de Expectativa de Vida - {ano_escolhido}', fontsize=10, fontweight='bold', pad=20)
plt.axis('equal')
plt.show()
# Out:
# Digite o ano que deseja visualizar, entre 1952 e 2007, em intervalos de 5 anos: 1982

# %% [markdown]
# # Extra: Importação de Base Online para Fazer Matriz e Análise Completa

# %%
# donwload de fonte externa do site kagglehub (https://www.kaggle.com/datasets/nelgiriyewithana/countries-of-the-world-2023) ou Outra Base https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv
! pip install kagglehub
import kagglehub

# Download latest version
path = kagglehub.dataset_download("nelgiriyewithana/countries-of-the-world-2023")

print("Path to dataset files:", path)
# Out:
# ...
# Using Colab cache for faster access to the 'countries-of-the-world-2023' dataset.
# Path to dataset files: /kaggle/input/countries-of-the-world-2023

# %%
df_kaggle = pd.read_csv(
    'https://raw.githubusercontent.com/owid/co2-data/master/owid-co2-data.csv',
    sep=',',
    encoding='latin-1'
)

# %%
df_kaggle.describe()
# Out:
#                year    population           gdp    cement_co2  \
# count  50411.000000  4.116700e+04  1.525100e+04  29173.000000
# mean    1920.349249  6.017453e+07  3.300495e+11      7.890109
# std       65.859123  3.308433e+08  3.086383e+12     62.988171
# min     1750.000000  2.150000e+02  4.998000e+07      0.000000
# 25%     1875.000000  3.272140e+05  7.874038e+09      0.000000
# 50%     1925.000000  2.291594e+06  2.743861e+10      0.000000
# 75%     1975.000000  9.986553e+06  1.212627e+11      0.524000
# max     2024.000000  8.161973e+09  1.301126e+14   1666.885000
#
#        cement_co2_per_capita           co2  co2_growth_abs  co2_growth_prct  \
# count           25648.000000  29384.000000    27216.000000     26239.000000
# mean                0.060013    420.227035        6.268847        42.598225
# std                 0.123562   1972.092032       62.199548      1721.913018
# min                 0.000000      0.000000    -1928.339000      -100.000000
# ...

# %%
df_kaggle.head()
# Out:
#        country  year iso_code  population  gdp  cement_co2  \
# 0  Afghanistan  1750      AFG   2802560.0  NaN         0.0
# 1  Afghanistan  1751      AFG         NaN  NaN         0.0
# 2  Afghanistan  1752      AFG         NaN  NaN         0.0
# 3  Afghanistan  1753      AFG         NaN  NaN         0.0
# 4  Afghanistan  1754      AFG         NaN  NaN         0.0
#
#    cement_co2_per_capita  co2  co2_growth_abs  co2_growth_prct  ...  \
# 0                    0.0  NaN             NaN              NaN  ...
# 1                    NaN  NaN             NaN              NaN  ...
# 2                    NaN  NaN             NaN              NaN  ...
# 3                    NaN  NaN             NaN              NaN  ...
# 4                    NaN  NaN             NaN              NaN  ...
#
#    share_global_other_co2  share_of_temperature_change_from_ghg  \
# 0                     NaN                                   NaN
# 1                     NaN                                   NaN
# ...

# %%
df_kaggle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50411 entries, 0 to 50410
# Data columns (total 79 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   country                                    50411 non-null  object
#  1   year                                       50411 non-null  int64
#  2   iso_code                                   42480 non-null  object
#  3   population                                 41167 non-null  float64
#  4   gdp                                        15251 non-null  float64
#  5   cement_co2                                 29173 non-null  float64
#  6   cement_co2_per_capita                      25648 non-null  float64
#  7   co2                                        29384 non-null  float64
#  8   co2_growth_abs                             27216 non-null  float64
#  9   co2_growth_prct                            26239 non-null  float64
# ...

# %%
df_kaggle_ajustado = df_kaggle.copy()

df_kaggle_ajustado = df_kaggle_ajustado.rename(
    columns={
        'country': 'País',
        'year': 'Ano',
        'iso_code': 'Código ISO',
        'population': 'População',
        'gdp': 'PIB',
        'cement_co2': 'CO2 do Cimento',
        'cement_co2_per_capita': 'CO2 do Cimento per Capita',
        'co2': 'CO2 Total',
        'co2_growth_abs': 'Crescimento Absoluto do CO2',
        'co2_growth_prct': 'Crescimento Percentual do CO2',
        'co2_including_luc': 'CO2 Incluindo Mudança no Uso da Terra',
        'co2_including_luc_growth_abs': 'Crescimento Absoluto do CO2 c/ Uso da Terra',
        'co2_including_luc_growth_prct': 'Crescimento Percentual do CO2 c/ Uso da Terra',
        'co2_including_luc_per_capita': 'CO2 c/ Uso da Terra per Capita',
        'co2_including_luc_per_gdp': 'CO2 c/ Uso da Terra por PIB',
        'co2_including_luc_per_unit_energy': 'CO2 c/ Uso da Terra por Unidade de Energia',
        'co2_per_capita': 'CO2 per Capita',
        'co2_per_gdp': 'CO2 por PIB',
        'co2_per_unit_energy': 'CO2 por Unidade de Energia',
        'coal_co2': 'CO2 do Carvão',
        'coal_co2_per_capita': 'CO2 do Carvão per Capita',
        'gas_co2': 'CO2 do Gás',
        'gas_co2_per_capita': 'CO2 do Gás per Capita',
        'oil_co2': 'CO2 do Petróleo',
        'oil_co2_per_capita': 'CO2 do Petróleo per Capita',
        'consumption_co2': 'CO2 de Consumo',
        'consumption_co2_per_capita': 'CO2 de Consumo per Capita',
        'consumption_co2_per_gdp': 'CO2 de Consumo por PIB',
        'cumulative_cement_co2': 'CO2 Acumulado do Cimento',
        'cumulative_co2': 'CO2 Acumulado',
        'cumulative_co2_including_luc': 'CO2 Acumulado c/ Uso da Terra',
        'cumulative_coal_co2': 'CO2 Acumulado do Carvão',
        'cumulative_flaring_co2': 'CO2 Acumulado de Queima',
        'cumulative_gas_co2': 'CO2 Acumulado do Gás',
        'cumulative_luc_co2': 'CO2 Acumulado por Uso da Terra',
        'cumulative_oil_co2': 'CO2 Acumulado do Petróleo',
        'cumulative_other_co2': 'Outros CO2 Acumulados',
        'energy_per_capita': 'Energia per Capita',
        'energy_per_gdp': 'Energia por PIB',
        'primary_energy_consumption': 'Consumo Primário de Energia',
        'flaring_co2': 'CO2 de Queima',
        'flaring_co2_per_capita': 'CO2 de Queima per Capita',
        'ghg_excluding_lucf_per_capita': 'GEE sem Uso da Terra per Capita',
        'ghg_per_capita': 'GEE per Capita',
        'total_ghg': 'Total de GEE',
        'total_ghg_excluding_lucf': 'Total de GEE sem Uso da Terra',
        'land_use_change_co2': 'CO2 por Mudança no Uso da Terra',
        'land_use_change_co2_per_capita': 'CO2 por Uso da Terra per Capita',
        'methane': 'Metano',
        'methane_per_capita': 'Metano per Capita',
        'nitrous_oxide': 'Óxido Nitroso',
        'nitrous_oxide_per_capita': 'Óxido Nitroso per Capita',
        'other_co2_per_capita': 'Outros CO2 per Capita',
        'other_industry_co2': 'CO2 de Outras Indústrias',
        'share_global_cement_co2': 'Participação Global CO2 Cimento',
        'share_global_co2': 'Participação Global CO2',
        'share_global_co2_including_luc': 'Participação Global CO2 c/ Uso da Terra',
        'share_global_coal_co2': 'Participação Global CO2 Carvão',
        'share_global_cumulative_cement_co2': 'Participação Global Acumulada CO2 Cimento',
        'share_global_cumulative_co2': 'Participação Global Acumulada CO2',
        'share_global_cumulative_co2_including_luc': 'Participação Global Acumulada CO2 c/ Uso da Terra',
        'share_global_cumulative_coal_co2': 'Participação Global Acumulada CO2 Carvão',
        'share_global_cumulative_flaring_co2': 'Participação Global Acumulada CO2 Queima',
        'share_global_cumulative_gas_co2': 'Participação Global Acumulada CO2 Gás',
        'share_global_cumulative_luc_co2': 'Participação Global Acumulada CO2 Uso da Terra',
        'share_global_cumulative_oil_co2': 'Participação Global Acumulada CO2 Petróleo',
        'share_global_cumulative_other_co2': 'Participação Global Acumulada Outros CO2',
        'share_global_flaring_co2': 'Participação Global CO2 Queima',
        'share_global_gas_co2': 'Participação Global CO2 Gás',
        'share_global_luc_co2': 'Participação Global CO2 Uso da Terra',
        'share_global_oil_co2': 'Participação Global CO2 Petróleo',
        'share_global_other_co2': 'Participação Global Outros CO2',
        'share_of_temperature_change_from_ghg': 'Participação na Mudança de Temperatura por GEE',
        'temperature_change_from_ch4': 'Mudança de Temperatura por CH4',
        'temperature_change_from_co2': 'Mudança de Temperatura por CO2',
        'temperature_change_from_ghg': 'Mudança de Temperatura por GEE',
        'temperature_change_from_n2o': 'Mudança de Temperatura por N2O',
        'trade_co2': 'CO2 de Comércio',
        'trade_co2_share': 'Participação do CO2 de Comércio',
        'Longitude': 'Longitude'
    }
)

# %%
df_kaggle_final = df_kaggle_ajustado[
    ['País','Ano','População','PIB','CO2 Total','CO2 per Capita','Total de GEE','Energia per Capita','Mudança de Temperatura por CO2']
]


coluna_chave = 'País' + '_' + 'Ano'
df_kaggle_final[coluna_chave] = df_kaggle_final['País'] + '_' + df_kaggle_final['Ano'].astype(str)
df_kaggle_final.head()
# Out:
# /tmp/ipykernel_4303/2117242150.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_kaggle_final[coluna_chave] = df_kaggle_final['País'] + '_' + df_kaggle_final['Ano'].astype(str)
#           País   Ano  População  PIB  CO2 Total  CO2 per Capita  Total de GEE  \
# 0  Afghanistan  1750  2802560.0  NaN        NaN             NaN           NaN
# 1  Afghanistan  1751        NaN  NaN        NaN             NaN           NaN
# 2  Afghanistan  1752        NaN  NaN        NaN             NaN           NaN
# 3  Afghanistan  1753        NaN  NaN        NaN             NaN           NaN
# 4  Afghanistan  1754        NaN  NaN        NaN             NaN           NaN
#
#    Energia per Capita  Mudança de Temperatura por CO2          País_Ano
# ...

# %%
df_tratado['País_Ano'] = df_tratado['País'] + '_' + df_tratado['Ano'].astype(str)
df_tratado.head()
# Out:
#           País   Ano  População total Continente  Expectativa de vida  \
# 0  Afghanistan  1952        8425333.0       Asia               28.801
# 1  Afghanistan  1957        9240934.0       Asia               30.332
# 2  Afghanistan  1962       10267083.0       Asia               31.997
# 3  Afghanistan  1967       11537966.0       Asia               34.020
# 4  Afghanistan  1972       13079460.0       Asia               36.088
#
#    Produto Interno Bruto per capita Condição          País_Ano
# 0                        779.445314    Baixa  Afghanistan_1952
# 1                        820.853030    Baixa  Afghanistan_1957
# 2                        853.100710    Baixa  Afghanistan_1962
# 3                        836.197138    Baixa  Afghanistan_1967
# 4                        739.981106    Média  Afghanistan_1972

# %%
df_tratado_combinado = df_tratado.merge(df_kaggle_final, on='País_Ano', how='inner')

# %%
df_tratado_combinado.head()
# Out:
#         País_x  Ano_x  População total Continente  Expectativa de vida  \
# 0  Afghanistan   1952        8425333.0       Asia               28.801
# 1  Afghanistan   1957        9240934.0       Asia               30.332
# 2  Afghanistan   1962       10267083.0       Asia               31.997
# 3  Afghanistan   1967       11537966.0       Asia               34.020
# 4  Afghanistan   1972       13079460.0       Asia               36.088
#
#    Produto Interno Bruto per capita Condição          País_Ano       País_y  \
# 0                        779.445314    Baixa  Afghanistan_1952  Afghanistan
# 1                        820.853030    Baixa  Afghanistan_1957  Afghanistan
# 2                        853.100710    Baixa  Afghanistan_1962  Afghanistan
# 3                        836.197138    Baixa  Afghanistan_1967  Afghanistan
# 4                        739.981106    Média  Afghanistan_1972  Afghanistan
#
#    Ano_y   População           PIB  CO2 Total  CO2 per Capita  Total de GEE  \
# ...

# %%
df_final = df_tratado_combinado.drop(columns=['Ano_y', 'País_y'])
df_final = df_final.rename(columns={'Ano_x': 'Ano', 'País_Ano_x': 'País_Ano', 'País_x':'País'})
df_final.head()
# Out:
#           País   Ano  População total Continente  Expectativa de vida  \
# 0  Afghanistan  1952        8425333.0       Asia               28.801
# 1  Afghanistan  1957        9240934.0       Asia               30.332
# 2  Afghanistan  1962       10267083.0       Asia               31.997
# 3  Afghanistan  1967       11537966.0       Asia               34.020
# 4  Afghanistan  1972       13079460.0       Asia               36.088
#
#    Produto Interno Bruto per capita Condição          País_Ano   População  \
# 0                        779.445314    Baixa  Afghanistan_1952   7987784.0
# 1                        820.853030    Baixa  Afghanistan_1957   8588340.0
# 2                        853.100710    Baixa  Afghanistan_1962   9404410.0
# 3                        836.197138    Baixa  Afghanistan_1967  10505961.0
# 4                        739.981106    Média  Afghanistan_1972  11853698.0
#
#             PIB  CO2 Total  CO2 per Capita  Total de GEE  Energia per Capita  \
# ...

# %%
df_final.set_index('País_Ano', inplace=True)
df_final.head()
# Out:
#                          País   Ano  População total Continente  \
# País_Ano
# Afghanistan_1952  Afghanistan  1952        8425333.0       Asia
# Afghanistan_1957  Afghanistan  1957        9240934.0       Asia
# Afghanistan_1962  Afghanistan  1962       10267083.0       Asia
# Afghanistan_1967  Afghanistan  1967       11537966.0       Asia
# Afghanistan_1972  Afghanistan  1972       13079460.0       Asia
#
#                   Expectativa de vida  Produto Interno Bruto per capita  \
# País_Ano
# Afghanistan_1952               28.801                        779.445314
# Afghanistan_1957               30.332                        820.853030
# Afghanistan_1962               31.997                        853.100710
# Afghanistan_1967               34.020                        836.197138
# Afghanistan_1972               36.088                        739.981106
#
#                  Condição   População           PIB  CO2 Total  \
# País_Ano
# ...

# %%
sns.heatmap(df_final.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # Gráficos Extras - Parte de Tratativa

# %%
df_final['País'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Australia', 'Austria', 'Bahrain', 'Bangladesh', 'Belgium',
#        'Benin', 'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Costa Rica', "Cote d'Ivoire", 'Croatia',
#        'Cuba', 'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador',
#        'Egypt', 'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Ethiopia',
#        'Finland', 'France', 'Gabon', 'Gambia', 'Germany', 'Ghana',
#        'Greece', 'Guatemala', 'Guinea', 'Guinea-Bissau', 'Haiti',
#        'Honduras', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jordan',
#        'Kenya', 'Kuwait', 'Lebanon', 'Lesotho', 'Liberia', 'Libya',
# ...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1560 entries, Afghanistan_1952 to Zimbabwe_2007
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   País                              1560 non-null   object
#  1   Ano                               1560 non-null   int64
#  2   População total                   1560 non-null   float64
#  3   Continente                        1560 non-null   object
#  4   Expectativa de vida               1560 non-null   float64
#  5   Produto Interno Bruto per capita  1560 non-null   float64
#  6   Condição                          1560 non-null   object
#  7   População                         1560 non-null   float64
#  8   PIB                               1524 non-null   float64
#  9   CO2 Total                         1521 non-null   float64
#  10  CO2 per Capita                    1521 non-null   float64
# ...

# %%
'''
df_final = df_final[df_final['País']=='Argentina']
print(df_final['CO2 Total'])
'''
# Out:
# "\ndf_final = df_final[df_final['País']=='Argentina']\nprint(df_final['CO2 Total'])\n"

# %% [markdown]
# # Gráficos Extras - Parte Final e Análise

# %%
# Gráfico: Comparação do índice de CO2 Total dentro de um ano selecionado e um conjunto de países escolhidos
ano_escolhido = int(input( "Digite o ano que deseja visualizar (1952 a 2007 em intervalos de 5 anos): "))
anos_validos = [1952, 1957, 1962, 1967, 1972,1977, 1982, 1987, 1992,1997, 2002, 2007]

if ano_escolhido in anos_validos:
    print("Ano válido")
else:
    print("Ano inválido")
    exit()

# Cuba,Argentina,Albania,Austria,Brazil,Chile,Togo,China,Italy,Poland,Japan
paises = input(f"Digite os países que deseja visualizar o índice de CO2 no ano de {ano_escolhido}, separados por virgula: ").split(',')
paises = [pais.strip().title() for pais in paises]
print("Países selecionados:", paises)

df_filtrado = df_final[(df_final['Ano'] == ano_escolhido) & (df_final['País'].isin(paises))]

if df_filtrado.empty:
    print("Nenhum dado encontrado para os países informados.")
else:
    plt.figure(figsize=(10, 8))
    barras = plt.bar(
        df_filtrado['País'],
        df_filtrado['CO2 Total'],
        color='darkred',
        edgecolor='black',
        linewidth=1,
        alpha=0.7
    )

    plt.bar_label(
    barras,
        labels=[f'{valor:.2f}' for valor in df_filtrado['CO2 Total']],
        padding=3,
        fontsize=8
    )

    plt.title(f'CO2 Total por País - {ano_escolhido}', fontsize=12, fontweight='bold')
    plt.xlabel('País', fontsize=10, fontweight='bold', labelpad=10)
    plt.ylabel('CO2 Total', fontsize=10, fontweight='bold', labelpad=10)
    plt.xticks(rotation=45, fontsize=8, fontstyle='italic')
    plt.yticks(fontsize=8, fontstyle='italic')
    plt.tight_layout()
    plt.show()
# Out:
# Digite o ano que deseja visualizar (1952 a 2007 em intervalos de 5 anos): 1982
# Ano válido
# Digite os países que deseja visualizar o índice de CO2 no ano de 1982, separados por virgula: Brazil,Cuba,Argentina,Albania,Austria,Brazil,Chile,Togo,China,Italy,Poland,Japan
# Países selecionados: ['Brazil', 'Cuba', 'Argentina', 'Albania', 'Austria', 'Brazil', 'Chile', 'Togo', 'China', 'Italy', 'Poland', 'Japan']

# %%
# Evolução de CO2 por País Selecionado ao longo dos anos

pais_escolhido = input("Digite os paises que deseja visualizar a evolução de CO2, em inglês e separado por virgula: ").split(',')
paises = [pais.strip().title() for pais in pais_escolhido]
print(f"Escolhidos na análise: {paises}")

df_filtro = df_final['País'].isin(paises)
df_filtro = df_final[df_filtro]

plt.figure(figsize=(10,8))
plt.title('Evolução do CO2 Total por País', fontsize=12, fontweight='bold')

for pais in paises:
    dados = df_filtro[df_filtro['País']==pais]
    plt.plot(dados['Ano'], dados['CO2 Total'], marker='o', linestyle='--', label=pais)

plt.xlabel('Ano', fontsize=9, fontweight='bold')
plt.xticks(evolucao.index, rotation=45, fontsize=7)
plt.ylabel('CO2 Total', fontsize=9, fontweight='bold')
plt.yticks(fontsize=7)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(title='País ou Paises Selecionados', fontsize=7, title_fontsize=8)
plt.tight_layout()
plt.show()
# Out:
# Digite os paises que deseja visualizar a evolução de CO2, em inglês e separado por virgula: Cuba,Argentina,Albania,Austria,Brazil
# Escolhidos na análise: ['Cuba', 'Argentina', 'Albania', 'Austria', 'Brazil']

# %%
# Comparação entre o índice de CO2 Total e a mudança de temperatura por CO2 para um conjunto de países e um ano específico escolhidos pelo usuário.
pais_escolhido = input("Digite os paises que deseja visualizar a evolução de CO2, em inglês e separado por virgula: ").split(',')
paises = [pais.strip().title() for pais in pais_escolhido]
print(f"Escolhidos na análise: {paises}")

ano_escolhido = int(input( "Digite o ano que deseja visualizar (1952 a 2007 em intervalos de 5 anos): "))
anos_validos = [1952, 1957, 1962, 1967, 1972,1977, 1982, 1987, 1992,1997, 2002, 2007]

if ano_escolhido in anos_validos:
    print(f"Ano válido - {ano_escolhido}")
else:
    print("Ano inválido")
    exit()

df_filtrado = df_final[(df_final['Ano'] == ano_escolhido) & (df_final['País'].isin(paises))]
# Condição é em relação a Expectativa de vida
g = sns.FacetGrid(df_filtrado, col='Condição', hue='País', height=5, aspect=1.5)
g.map_dataframe(sns.scatterplot, x='CO2 Total', y='Mudança de Temperatura por CO2')
g.add_legend()
plt.show();
# Out:
# Digite os paises que deseja visualizar a evolução de CO2, em inglês e separado por virgula: China,Unites States,Japan,Germany,Italy,Mexico,Spain,France
# Escolhidos na análise: ['China', 'Unites States', 'Japan', 'Germany', 'Italy', 'Mexico', 'Spain', 'France']
# Digite o ano que deseja visualizar (1952 a 2007 em intervalos de 5 anos): 2002
# Ano válido - 2002
