# %%
'''
    Nome: Matheus Lopes Lourenço
    Matrícula: 1666264
    RA: 256335
    E-mail: 1666264@sga.pucminas.br
    Nome da atividade: Aula 03 - Exercício
'''
# Out:
# '\n    Nome: Matheus Lopes Lourenço\n    Matrícula: 1666264\n    RA: 256335\n    E-mail: 1666264@sga.pucminas.br\n    Nome da atividade: Aula 03 - Exercício\n'

# %%
'''
1.	Considerando os dados carregados na prática 2 na conta de armazenamento 
stgaccountXXXXXX > datalake-XXXXXXX, onde (XXXXXX) é o seu código de matrícula/pessoa 
(encontrado no seu endereço de e-mail @sga.pucminas.br):

    i.	 DADOS_ESTUDANTES
    ii.	 DADOS_VOOS
    iii. DADOS_EXAMES
    iv.	 DADOS_ALUNOS
    v.	 DADOS_BANCARIOS

    a)	Leia cada um dos arquivos.
    b)	Exiba uma amostra de cada arquivo.
    c)	Imprima o esquema dos dados.
    d)	Ajuste o esquema (analise o conteúdo e classifique como você entender qual o tipo correto deve 
    ser atribuído aos campos de cada arquivo), se necessário.
    Você deverá exibir um print de cada uma das instruções (ou mantenha tudo resolvido no arquivo .ipynb).
'''
# Out:
# '\n1.\tConsiderando os dados carregados na prática 2 na conta de armazenamento \nstgaccountXXXXXX > datalake-XXXXXXX, onde (XXXXXX) é o seu código de matrícula/pessoa \n(encontrado no seu endereço de e-mail @sga.pucminas.br):\n\n    i.\t DADOS_ESTUDANTES\n    ii.\t DADOS_VOOS\n    iii. DADOS_EXAMES\n    iv.\t DADOS_ALUNOS\n    v.\t DADOS_BANCARIOS\n\n    a)\tLeia cada um dos arquivos.\n    b)\tExiba uma amostra de cada arquivo.\n    c)\tImprima o esquema dos dados.\n    d)\tAjuste o esquema (analise o conteúdo e classifique como você entender qual o tipo correto deve \n    ser atribuído aos campos de cada arquivo), se necessário.\n    Você deverá exibir um print de cada uma das instruções (ou mantenha tudo resolvido no arquivo .ipynb).\n\n'

# %%
'''
2.	Considere as bases de dados disponibilizadas no módulo 2 
(Aula 2 – Criação de recursos em nuvem > Material de apoio > Bases de dados):
    a.	DADOS_EXAMES.csv
    b.	DADOS_ALUNOS.xml

Aplique as técnicas de normalização de dados. Você deverá entregar um print exibido todos os 
objetos após a normalização das informações.

'''
# Out:
# '\n2.\tConsidere as bases de dados disponibilizadas no módulo 2 \n(Aula 2 – Criação de recursos em nuvem > Material de apoio > Bases de dados):\n    a.\tDADOS_EXAMES.csv\n    b.\tDADOS_ALUNOS.xml\n\nAplique as técnicas de normalização de dados. Você deverá entregar um print exibido todos os \nobjetos após a normalização das informações.\n\n'
