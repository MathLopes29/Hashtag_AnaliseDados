# %% [markdown]
# -------------------------------------------------------------------------
# *   PONTIFÍCIA UNIVERSIDADE CATÓLICA DE MINAS GERAIS
# *   PROFESSOR: VICTOR SALES SILVA
# *   ALUNO: Matheus Lopes Lourenço
# *   MATRICULA: 1666264
# *   E-MAIL: 1666264@sga.pucminas.br
# *   ATIVIDADE: EXEMPLO DE LEITURA DE ARQUIVO EM FORMATO JSON UTILIZANDO PANDAS
# -------------------------------------------------------------------------

# %% [markdown]
# # IMPORTAÇÃO DAS BIBLIOTECAS

# %%
import pandas as pd

# %% [markdown]
# # DEFINIÇÃO DAS VARIÁVEIS

# %%
arquivo = 'C:\\Users\\negri\\OneDrive\\Documentos\\GitHub\\Hashtag_AnaliseDados\\Python\\Cursos\\PUC Ciência de Dados\\Projetos\\Preparação e Integração de Dados\\02_Aula\\Bases de dados\\DADOS_EXAMES.csv'

# %% [markdown]
# # LEITURA DO ARQUIVO CSV USANDO PANDAS

# %%
df = pd.read_csv(arquivo, sep=';')

# %% [markdown]
# # EXIBINDO UMA AMOSTRA DOS DADOS

# %%
df.head(5)
# Out:
#    IdUnidadeAtendimento          Cidade Estado        Bairro NumPedidoMedico  \
# 0                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS        PED-6217
# 1                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-11486
# 2                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-11818
# 3                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-11937
# 4                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-12091
#
#    IdExame                  Exame SiglaExame Material     SetorExame  \
# 0     3368        URINA - CULTURA        CTU    URINA  MICROBIOLOGIA
# 1     3369         PARASITOLÓGICO         FP    FEZES     COPROLOGIA
# 2     3368        URINA - CULTURA        CTU    URINA  MICROBIOLOGIA
# 3     3368        URINA - CULTURA        CTU    URINA  MICROBIOLOGIA
# 4     3370  GRAM - BACTERIOSCOPIA     GRAM-U    URINA  MICROBIOLOGIA
#
#    QtdAmostrasColhidas  QtdExames PrecoExame    DataPrevistaResultado  \
# 0                    1          1     9,1419  2022-03-29 22:43:00.000
# 1                    1          1     7,6343  2022-02-22 14:43:00.000
# 2                    1          1     9,1419  2022-03-08 14:43:00.000
# 3                    1          1     9,1419  2022-01-11 14:43:00.000
# 4                    1          1     1,7025  2023-01-05 20:43:00.000
#
#     DataLiberacaoResultado
# 0  2022-03-25 18:18:00.000
# 1  2022-02-22 09:01:43.000
# 2  2022-02-28 05:52:40.000
# 3  2022-01-05 07:20:58.000
# 4  2023-01-05 15:16:01.000

# %% [markdown]
# # EXIBINDO OS METADADOS (SCHEMA) DO ARQUIVO

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   IdUnidadeAtendimento    500000 non-null  int64
#  1   Cidade                  500000 non-null  object
#  2   Estado                  500000 non-null  object
#  3   Bairro                  500000 non-null  object
#  4   NumPedidoMedico         500000 non-null  object
#  5   IdExame                 500000 non-null  int64
#  6   Exame                   500000 non-null  object
#  7   SiglaExame              500000 non-null  object
#  8   Material                500000 non-null  object
#  9   SetorExame              500000 non-null  object
#  10  QtdAmostrasColhidas     500000 non-null  int64
#  11  QtdExames               500000 non-null  int64
#  12  PrecoExame              500000 non-null  object
#  13  DataPrevistaResultado   500000 non-null  object
#  14  DataLiberacaoResultado  500000 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 57.2+ MB

# %%
df.head(10)
# Out:
#    IdUnidadeAtendimento          Cidade Estado        Bairro NumPedidoMedico  \
# 0                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS        PED-6217
# 1                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-11486
# 2                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-11818
# 3                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-11937
# 4                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-12091
# 5                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-12091
# 6                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-14385
# 7                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-14488
# 8                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-14494
# 9                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-14564
#
#    IdExame                    Exame SiglaExame  Material          SetorExame  \
# 0     3368          URINA - CULTURA        CTU     URINA       MICROBIOLOGIA
# 1     3369           PARASITOLÓGICO         FP     FEZES          COPROLOGIA
# 2     3368          URINA - CULTURA        CTU     URINA       MICROBIOLOGIA
# 3     3368          URINA - CULTURA        CTU     URINA       MICROBIOLOGIA
# 4     3370    GRAM - BACTERIOSCOPIA     GRAM-U     URINA       MICROBIOLOGIA
# 5     3368          URINA - CULTURA        CTU     URINA       MICROBIOLOGIA
# 6     3371             ZINCO (SORO)      ZN-SO    SANGUE         TOXICOLOGIA
# 7     3372                HEMOGRAMA         HG    SANGUE      LINHA VERMELHA
# 8     3373   TESTE DE SEXAGEM FETAL        TSF    SANGUE  BIOLOGIA MOLECULAR
# 9     3374  MICOBACTÉRIAS - CULTURA      CT-BK  DIVERSOS       MICROBIOLOGIA
#
#    QtdAmostrasColhidas  QtdExames PrecoExame    DataPrevistaResultado  \
# 0                    1          1     9,1419  2022-03-29 22:43:00.000
# 1                    1          1     7,6343  2022-02-22 14:43:00.000
# 2                    1          1     9,1419  2022-03-08 14:43:00.000
# 3                    1          1     9,1419  2022-01-11 14:43:00.000
# 4                    1          1     1,7025  2023-01-05 20:43:00.000
# 5                    1          1     9,1419  2023-01-11 14:43:00.000
# 6                    1          1     8,0752  2022-01-09 14:43:00.000
# 7                    1          1     7,6797  2022-02-08 14:43:00.000
# 8                    1          1     7,9637  2022-03-30 14:43:00.000
# 9                    1          1     7,5503  2021-06-28 14:43:00.000
#
#     DataLiberacaoResultado
# 0  2022-03-25 18:18:00.000
# 1  2022-02-22 09:01:43.000
# 2  2022-02-28 05:52:40.000
# 3  2022-01-05 07:20:58.000
# 4  2023-01-05 15:16:01.000
# 5  2023-01-08 07:15:27.000
# 6  2022-01-08 02:36:45.000
# 7  2022-02-07 15:39:16.000
# 8  2022-03-30 10:14:45.000
# 9  2021-06-15 13:10:34.000

# %% [markdown]
# # AJUSTAR O SCHEMA DOS DADOS, SE NECESSÁRIO

# %%
df['Cidade'] = df['Cidade'].astype('string')
df['Estado'] = df['Estado'].astype('string')
df['Bairro'] = df['Bairro'].astype('string')
df['NumPedidoMedico'] = df['NumPedidoMedico'].astype('string')
df['Exame'] = df['Exame'].astype('string')
df['SiglaExame'] = df['SiglaExame'].astype('string')
df['Material'] = df['Material'].astype('string')
df['SetorExame'] = df['SetorExame'].astype('string')
df['PrecoExame'] = df['PrecoExame'].str.replace(',','.').astype('double')
df['DataPrevistaResultado'] = df['DataPrevistaResultado'].astype('datetime64[ns]')
df['DataLiberacaoResultado'] = df['DataLiberacaoResultado'].astype('datetime64[ns]')

# %%
display(df.head(10))
# Out:
#    IdUnidadeAtendimento          Cidade Estado        Bairro NumPedidoMedico  \
# 0                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS        PED-6217
# 1                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-11486
# 2                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-11818
# 3                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-11937
# 4                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-12091
# 5                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-12091
# 6                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-14385
# 7                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-14488
# 8                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-14494
# 9                   713  BELO HORIZONTE     MG  FUNCIONÁRIOS       PED-14564
#
#    IdExame                    Exame SiglaExame  Material          SetorExame  \
# 0     3368          URINA - CULTURA        CTU     URINA       MICROBIOLOGIA
# 1     3369           PARASITOLÓGICO         FP     FEZES          COPROLOGIA
# 2     3368          URINA - CULTURA        CTU     URINA       MICROBIOLOGIA
# 3     3368          URINA - CULTURA        CTU     URINA       MICROBIOLOGIA
# 4     3370    GRAM - BACTERIOSCOPIA     GRAM-U     URINA       MICROBIOLOGIA
# 5     3368          URINA - CULTURA        CTU     URINA       MICROBIOLOGIA
# 6     3371             ZINCO (SORO)      ZN-SO    SANGUE         TOXICOLOGIA
# 7     3372                HEMOGRAMA         HG    SANGUE      LINHA VERMELHA
# 8     3373   TESTE DE SEXAGEM FETAL        TSF    SANGUE  BIOLOGIA MOLECULAR
# 9     3374  MICOBACTÉRIAS - CULTURA      CT-BK  DIVERSOS       MICROBIOLOGIA
#
#    QtdAmostrasColhidas  QtdExames  PrecoExame DataPrevistaResultado  \
# 0                    1          1      9.1419   2022-03-29 22:43:00
# 1                    1          1      7.6343   2022-02-22 14:43:00
# 2                    1          1      9.1419   2022-03-08 14:43:00
# 3                    1          1      9.1419   2022-01-11 14:43:00
# 4                    1          1      1.7025   2023-01-05 20:43:00
# 5                    1          1      9.1419   2023-01-11 14:43:00
# 6                    1          1      8.0752   2022-01-09 14:43:00
# 7                    1          1      7.6797   2022-02-08 14:43:00
# 8                    1          1      7.9637   2022-03-30 14:43:00
# 9                    1          1      7.5503   2021-06-28 14:43:00
#
#   DataLiberacaoResultado
# 0    2022-03-25 18:18:00
# 1    2022-02-22 09:01:43
# 2    2022-02-28 05:52:40
# 3    2022-01-05 07:20:58
# 4    2023-01-05 15:16:01
# 5    2023-01-08 07:15:27
# 6    2022-01-08 02:36:45
# 7    2022-02-07 15:39:16
# 8    2022-03-30 10:14:45
# 9    2021-06-15 13:10:34

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500000 entries, 0 to 499999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   IdUnidadeAtendimento    500000 non-null  int64
#  1   Cidade                  500000 non-null  string
#  2   Estado                  500000 non-null  string
#  3   Bairro                  500000 non-null  string
#  4   NumPedidoMedico         500000 non-null  string
#  5   IdExame                 500000 non-null  int64
#  6   Exame                   500000 non-null  string
#  7   SiglaExame              500000 non-null  string
#  8   Material                500000 non-null  string
#  9   SetorExame              500000 non-null  string
#  10  QtdAmostrasColhidas     500000 non-null  int64
#  11  QtdExames               500000 non-null  int64
#  12  PrecoExame              500000 non-null  float64
#  13  DataPrevistaResultado   500000 non-null  datetime64[ns]
#  14  DataLiberacaoResultado  500000 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(1), int64(4), string(8)
# memory usage: 57.2 MB
