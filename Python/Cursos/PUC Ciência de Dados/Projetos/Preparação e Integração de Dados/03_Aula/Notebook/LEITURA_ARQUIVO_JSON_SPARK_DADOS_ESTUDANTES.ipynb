# %% [markdown]
# -------------------------------------------------------------------------
# *   PONTIFÍCIA UNIVERSIDADE CATÓLICA DE MINAS GERAIS
# *   PROFESSOR: VICTOR SALES SILVA
# *   ALUNO: Matheus Lopes Lourenço
# *   MATRICULA: 1666264
# *   E-MAIL: 1666264@sga.pucminas.br
# *   ATIVIDADE: EXEMPLO DE LEITURA DE ARQUIVO EM FORMATO JSON UTILIZANDO SPARK
# -------------------------------------------------------------------------

# %% [markdown]
# # INSTALAÇÃO DAS BIBLIOTECAS

# %%
# %pip install pyspark

# %% [markdown]
# # IMPORTAÇÃO DAS BIBLIOTECAS

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# # CRIAÇÃO DA APLICAÇÃO SPARK

# %%
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# # VARIÁVEIS DE APOIO

# %%
arquivo = 'C:\\Users\\negri\\OneDrive\\Documentos\\GitHub\\Hashtag_AnaliseDados\\Python\\Cursos\\PUC Ciência de Dados\\Projetos\\Preparação e Integração de Dados\\02_Aula\\Bases de dados\\DADOS_ESTUDANTES.json'

options = {
    "encoding": "Latin1",
    "multiline": "true"
}

# %% [markdown]
# # LEITURA DO ARQUIVO JSON USANDO SPARK

# %%
df = spark.read.options(**options).json(arquivo)

# %% [markdown]
# # EXIBINDO UMA AMOSTRA DOS DADOS

# %%
df.show()

# %% [markdown]
# # EXIBINDO OS METADADOS (SCHEMA) DO ARQUIVO

# %%
df.printSchema()

# %% [markdown]
# # AJUSTAR O SCHEMA DOS DADOS, SE NECESSÁRIO
