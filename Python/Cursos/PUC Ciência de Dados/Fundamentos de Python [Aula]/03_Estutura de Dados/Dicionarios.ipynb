# %% [markdown]
# #
# <font color="##188038"><h4><B> Dicionários (`dict`)</b></h4></font>
# ***
# Dicionários armazenam dados em pares **chave:valor**. São mutáveis e não ordenados até o Python 3.7+ (agora mantêm ordem de inserção).
#
# Usos no mundo real:
#
# - Cadastro de usuários: Nome, idade, email associados a uma chave única.
#
# - Resposta de APIs: Dados estruturados vêm em formato de dicionário (JSON).
#
# - Configurações de sistema: Parâmetros nomeados e seus respectivos valores.
#
# - Dados de banco de dados em memória.
#
# ```python
# # Exemplo
# usuario = {
#     "nome": "Maria",
#     "email": "maria@gmail.com",
#     "idade": 30
# }
# ```
#
# ##### Funções/métodos úteis:
# <center>
#
#
# | Função/Método       | Descrição                             |
# |---------------------|-----------------------------------------|
# | `keys()`            | Retorna as chaves                      |
# | `values()`          | Retorna os valores                     |
# | `items()`           | Retorna pares (chave, valor)           |
# | `get()`             | Retorna o valor de uma chave           |
# | `update()`          | Atualiza o dicionário com novos pares  |
# | `pop()`             | Remove um item pela chave              |

# %% [markdown]
# ##### Exemplo prático:

# %% [markdown]
# `keys()` — Retorna todas as chaves

# %%
niveis_co2 = {
    'AC': [325,405,429,486,402],
    'AL': [492,495,310,407,388],
    'AP': [507,503,368,338,400],
    'AM': [429,456,352,377,363],
    'BA': [321,508,372,490,412],
    'CE': [424,328,425,516,480],
    'ES': [449,506,461,337,336],
    'GO': [425,460,385,485,460],
    'MA': [361,310,344,425,490],
    'MT': [358,402,425,386,379],
    'MS': [324,357,441,405,427],
    'MG': [345,367,391,427,516],
    'PA': [479,514,392,493,329],
    'PB': [418,499,317,302,476],
    'PR': [420,508,419,396,327],
    'PE': [404,444,495,320,343],
    'PI': [513,513,304,377,475],
    'RJ': [502,481,492,502,506],
    'RN': [446,437,519,356,317],
    'RS': [427,518,459,317,321],
    'RO': [517,466,512,326,458],
    'RR': [466,495,469,495,310],
    'SC': [495,436,382,483,479],
    'SP': [495,407,362,389,317],
    'SE': [508,351,334,389,418],
    'TO': [339,490,304,488,419],
    'DF': [376,516,320,310,518], 
}

for estado, niveis in niveis_co2.items():
    media = sum(niveis) / len(niveis)
    if media > 350:
        print(f"A média de níveis de CO2 em {estado} é {media:.2f} ppm.")
# Out:
# A média de níveis de CO2 em AC é 409.40 ppm.
# A média de níveis de CO2 em AL é 418.40 ppm.
# A média de níveis de CO2 em AP é 423.20 ppm.
# A média de níveis de CO2 em AM é 395.40 ppm.
# A média de níveis de CO2 em BA é 420.60 ppm.
# A média de níveis de CO2 em CE é 434.60 ppm.
# A média de níveis de CO2 em ES é 417.80 ppm.
# A média de níveis de CO2 em GO é 443.00 ppm.
# A média de níveis de CO2 em MA é 386.00 ppm.
# A média de níveis de CO2 em MT é 390.00 ppm.
# A média de níveis de CO2 em MS é 390.80 ppm.
# A média de níveis de CO2 em MG é 409.20 ppm.
# A média de níveis de CO2 em PA é 441.40 ppm.
# A média de níveis de CO2 em PB é 402.40 ppm.
# A média de níveis de CO2 em PR é 414.00 ppm.
# A média de níveis de CO2 em PE é 401.20 ppm.
# A média de níveis de CO2 em PI é 436.40 ppm.
# A média de níveis de CO2 em RJ é 496.60 ppm.
# A média de níveis de CO2 em RN é 415.00 ppm.
# A média de níveis de CO2 em RS é 408.40 ppm.
# A média de níveis de CO2 em RO é 455.80 ppm.
# ...

# %% [markdown]
# `values()` — Retorna todos os valores

# %%
print(niveis_co2.values())
# Out:
# dict_values([[325, 405, 429, 486, 402], [492, 495, 310, 407, 388], [507, 503, 368, 338, 400], [429, 456, 352, 377, 363], [321, 508, 372, 490, 412], [424, 328, 425, 516, 480], [449, 506, 461, 337, 336], [425, 460, 385, 485, 460], [361, 310, 344, 425, 490], [358, 402, 425, 386, 379], [324, 357, 441, 405, 427], [345, 367, 391, 427, 516], [479, 514, 392, 493, 329], [418, 499, 317, 302, 476], [420, 508, 419, 396, 327], [404, 444, 495, 320, 343], [513, 513, 304, 377, 475], [502, 481, 492, 502, 506], [446, 437, 519, 356, 317], [427, 518, 459, 317, 321], [517, 466, 512, 326, 458], [466, 495, 469, 495, 310], [495, 436, 382, 483, 479], [495, 407, 362, 389, 317], [508, 351, 334, 389, 418], [339, 490, 304, 488, 419], [376, 516, 320, 310, 518]])

# %% [markdown]
# `items()` — Retorna todos os pares (chave, valor)

# %%
niveis_co2.items()
# Out:
# dict_items([('AC', [325, 405, 429, 486, 402]), ('AL', [492, 495, 310, 407, 388]), ('AP', [507, 503, 368, 338, 400]), ('AM', [429, 456, 352, 377, 363]), ('BA', [321, 508, 372, 490, 412]), ('CE', [424, 328, 425, 516, 480]), ('ES', [449, 506, 461, 337, 336]), ('GO', [425, 460, 385, 485, 460]), ('MA', [361, 310, 344, 425, 490]), ('MT', [358, 402, 425, 386, 379]), ('MS', [324, 357, 441, 405, 427]), ('MG', [345, 367, 391, 427, 516]), ('PA', [479, 514, 392, 493, 329]), ('PB', [418, 499, 317, 302, 476]), ('PR', [420, 508, 419, 396, 327]), ('PE', [404, 444, 495, 320, 343]), ('PI', [513, 513, 304, 377, 475]), ('RJ', [502, 481, 492, 502, 506]), ('RN', [446, 437, 519, 356, 317]), ('RS', [427, 518, 459, 317, 321]), ('RO', [517, 466, 512, 326, 458]), ('RR', [466, 495, 469, 495, 310]), ('SC', [495, 436, 382, 483, 479]), ('SP', [495, 407, 362, 389, 317]), ('SE', [508, 351, 334, 389, 418]), ('TO', [339, 490, 304, 488, 419]), ('DF', [376, 516, 320, 310, 518])])

# %% [markdown]
# `get()` — Retorna o valor de uma chave

# %%
niveis_co2.get(input('Digite a sigla do estado').upper().strip(), 'Não Encontrado!')
# Out:
# [495, 407, 362, 389, 317]

# %% [markdown]
# `update()` — Atualiza ou adiciona pares chave:valor

# %%
niveis_co2.update({'OO':[450, 300, 250, 231, 380] })

# %%
niveis_co2
# Out:
# {'AC': [325, 405, 429, 486, 402],
#  'AL': [492, 495, 310, 407, 388],
#  'AP': [507, 503, 368, 338, 400],
#  'AM': [429, 456, 352, 377, 363],
#  'BA': [321, 508, 372, 490, 412],
#  'CE': [424, 328, 425, 516, 480],
#  'ES': [449, 506, 461, 337, 336],
#  'GO': [425, 460, 385, 485, 460],
#  'MA': [361, 310, 344, 425, 490],
#  'MT': [358, 402, 425, 386, 379],
#  'MS': [324, 357, 441, 405, 427],
#  'MG': [345, 367, 391, 427, 516],
#  'PA': [479, 514, 392, 493, 329],
#  'PB': [418, 499, 317, 302, 476],
#  'PR': [420, 508, 419, 396, 327],
#  'PE': [404, 444, 495, 320, 343],
#  'PI': [513, 513, 304, 377, 475],
#  'RJ': [502, 481, 492, 502, 506],
#  'RN': [446, 437, 519, 356, 317],
#  'RS': [427, 518, 459, 317, 321],
#  'RO': [517, 466, 512, 326, 458],
#  'RR': [466, 495, 469, 495, 310],
#  'SC': [495, 436, 382, 483, 479],
#  'SP': [495, 407, 362, 389, 317],
#  'SE': [508, 351, 334, 389, 418],
#  'TO': [339, 490, 304, 488, 419],
#  'DF': [376, 516, 320, 310, 518],
# ...

# %% [markdown]
# `pop()` — Remove uma chave e retorna seu valor

# %%
niveis_co2.pop('OO')
# Out:
# [450, 300, 250, 231, 380]

# %% [markdown]
# #
# <font color="##188038"><h4><B>Trabalhando com Dicionários que Armazenam Múltiplos Valores em Python</b></h4></font>
# ***
#
# Em Python, os **dicionários** são estruturas poderosas para armazenar dados relacionados por meio de pares `chave: valor`. Porém, em muitas situações do mundo real, cada chave pode estar associada a **mais de um valor** — como uma pessoa com vários telefones, um aluno com várias notas, ou um usuário com diversos cursos.
#
# Para isso, usamos outras estruturas (como **listas**, **tuplas** ou até **outros dicionários**) como valor de cada chave, criando dicionários **aninhados ou compostos**.
#
# Essa abordagem permite representar dados de forma mais rica, organizada e acessível.

# %% [markdown]
# <font color="yellow"><h7>Exemplo 1: Lista como valor</h7></font>
#
# Um cliente pode ter vários pedidos:

# %% [markdown]
# ***

# %% [markdown]
# <font color="yellow"><h7>Exemplo 2: Dicionário dentro de dicionário</h7></font>
#
# Informações mais completas de um usuário, como nome, idade e cursos feitos:

# %% [markdown]
# ***

# %% [markdown]
# <font color="yellow"><h7>Exemplo 3: Tuplas como valor</h7></font>
#
# Localizações em coordenadas (imutáveis):

# %% [markdown]
# ***

# %% [markdown]
# <font color="yellow"><h7>Exemplo 4: Lista de dicionários</h7></font>
#
# Cada item da lista representa um registro mais detalhado:

# %% [markdown]
# ***
