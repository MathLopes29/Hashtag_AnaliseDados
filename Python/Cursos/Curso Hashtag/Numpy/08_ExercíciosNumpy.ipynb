# %% [markdown]
# ## Exercício
#
# Você é um analista de RH e tem os salários de todos os funcionários da sua empresa em um array NumPy. Seu trabalho é identificar quantos funcionários ganham acima da média. Use o seguinte array para sua análise: `salarios = np.array([3000, 2500, 3500, 4000, 2000, 4500, 3000, 3800, 4800])`.

# %%
import numpy as np

salarios = np.array([3000, 2500, 3500, 4000, 2000, 4500, 3000, 3800, 4800])

media = np.mean(salarios)
condicao = np.where(salarios > media)

print(f"Média Salarial: {media:.2f}")
print(f"Salários acima da média ({salarios[condicao]})")
# Out:
# Média Salarial: 3455.56
# Salários acima da média ([3500 4000 4500 3800 4800])

# %%
print(f"Quantidade de funcionários que ganham acima da média: {np.sum(salarios > media)}")
# Out:
# Quantidade de funcionários que ganham acima da média: 5

# %%
print(np.count_nonzero(salarios > media))
print(np.unique(salarios > media, return_counts = True))

valores_unicos, contagem = np.unique(salarios > media, return_counts=True)
print(valores_unicos)
print(contagem)
# Out:
# 5
# (array([False,  True]), array([4, 5]))
# [False  True]
# [4 5]

# %%
rgn = np.random.default_rng(seed=42)
valores = rgn.integers(low = min (salarios), high = max(salarios), size=20, endpoint = True)
print(valores)

print(np.mean(valores))
# Out:
# [2249 4167 3833 3229 3212 4404 2240 3953 2564 2263 3474 4732 4060 4131
#  4009 4201 3437 2358 4352 3261]
# 3506.45
