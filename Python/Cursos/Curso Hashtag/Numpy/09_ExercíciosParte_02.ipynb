# %% [markdown]
# ## Exercício
#
# Você é um engenheiro de produção e tem os tempos de ciclo (em minutos) de uma linha de produção em um array NumPy. Seu trabalho é identificar quaisquer tempos de ciclo que estão dois desvios padrão acima ou abaixo da média. Use o seguinte array para sua análise: `tempos_ciclo = np.array([5.5, 5.7, 5.9, 6.0, 5.8, 5.6, 5.7, 7.2, 4.8])`.

# %%
import numpy as np

tempos_ciclo = np.array([5.5, 5.7, 5.9, 6.0, 5.8, 5.6, 5.7, 7.2, 4.8])
media = np.mean(tempos_ciclo)
print(f"Média: {media:.2f}") 

desvio = np.std(tempos_ciclo)
print(f"Desvio Padrão: {desvio:.2f}")

condicao = np.where((tempos_ciclo > media + 2*desvio) | (tempos_ciclo < media - 2*desvio))
print(f"Anomalias: {tempos_ciclo[condicao]}")
# Out:
# Média: 5.80
# Desvio Padrão: 0.59
# Anomalias: [7.2]

# %%
condicao = np.where((tempos_ciclo < media + 2*desvio) & (tempos_ciclo > media - 2*desvio))
print(f"Valores Dentro do Padrão: {tempos_ciclo[condicao]}")
# Out:
# Valores Dentro do Padrão: [5.5 5.7 5.9 6.  5.8 5.6 5.7 4.8]

# %%
condicao = (tempos_ciclo > media + 2*desvio) | (tempos_ciclo < media - 2*desvio)
print(f"Condição de Anomalia:{condicao}")
print(np.sum(condicao))

condicao = (tempos_ciclo <= media + 2*desvio) & (tempos_ciclo >= media - 2*desvio)
print(f"Dentro do Padrão: {condicao}")
print(np.sum(condicao))
# Out:
# Condição de Anomalia:[False False False False False False False  True False]
# 1
# Dentro do Padrão: [ True  True  True  True  True  True  True False  True]
# 8

# %%
rng = np.random.default_rng(seed=42)
tempos_gerados = rng.normal(loc=media, scale=desvio, size=20)
print(tempos_gerados)

media = tempos_gerados.mean()
desvio = tempos_gerados.std()

#condicao = (tempos_gerados > media - 2*desvio) & (tempos_gerados < media + 2*desvio)
#print(tempos_gerados[condicao])
# Out:
# [5.33428313 4.93618824 5.46624142 5.52252398 4.66647421 4.85856606
#  5.2819193  5.15044982 5.23909859 4.99153134 5.50441574 5.47433557
#  5.26362072 5.57778901 5.38247731 4.98968148 5.35324012 4.96019811
#  5.50413519 5.2292921 ]
