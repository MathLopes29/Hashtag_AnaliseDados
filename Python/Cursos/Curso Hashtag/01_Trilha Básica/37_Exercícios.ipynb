# %%
lista1=[('maçã', 10), ('banana', 5), ('laranja', 8)]
lista2=[('arroz', 20), ('feijão', 15), ('macarrão', 12)]

def listar_produtos(*listas):
    lista_final = []
    for lista in listas:
        for item, estoque in lista:
            lista_final.append(item)

    lista_final = set(lista_final)
    lista_final = list(lista_final)
    lista_final.sort()

    return lista_final

print(listar_produtos(lista1, lista2))
# Out:
# ['arroz', 'banana', 'feijão', 'laranja', 'macarrão', 'maçã']
