# %% [markdown]
# ### Documentação Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
import os

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)
caminho = r"https://www.youtube.com/watch?v=SKrgyeKbmRw"
navegador.get(caminho)

# %% [markdown]
# #### Pegar informações de um elemento
#
# - texto
# - atributos

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ##### Ex1: Link do Whatsapp

# %%
texto = navegador.find_element(By.XPATH, '//*[@id="aura-start"]/div[1]/button/span').get_attribute('href')
print(texto)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 texto = navegador.find_element(By.XPATH, '//*[@id="aura-start"]/div[1]/button/span').get_attribute('href')
#       2 print(texto)
#
# File c:\Users\negri\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:802, in WebDriver.find_element(self, by, value)
#     799         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     800     return elements[0]
# --> 802 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\negri\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:432, in WebDriver.execute(self, driver_command, params)
#     429 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
# ...

# %% [markdown]
# ##### Ex2: Imagens dos cursos

# %%
link = navegador.find_element(By.XPATH, '//*[@id="inline-preview-player"]/div[1]/video').get_attribute('src')
print(link)
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 link = navegador.find_element(By.XPATH, '/html/body/section[2]/div/div[4]/figure/a').get_attribute('src')
#       2 print(link)
#
# File c:\Users\negri\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:802, in WebDriver.find_element(self, by, value)
#     799         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     800     return elements[0]
# --> 802 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File c:\Users\negri\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:432, in WebDriver.execute(self, driver_command, params)
#     429 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
# ...
