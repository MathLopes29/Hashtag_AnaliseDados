# %%
pip install webdriver-manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install selenium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

navegador.get("https://www.google.com")

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from urllib.parse import quote_plus

options = Options()
options.add_argument("--start-maximized")

navegador = webdriver.Chrome(options=options)

termo = "spfc"
navegador.get(
    f"https://www.google.com/search?q={quote_plus(termo)}"
)

# %%
navegador.find_element() # Use this method to locate element on the page  1 item
navegador.find_elements() # Use this method to locate element on the page  +1 item

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time

# (opcional) opções do Chrome
options = Options()
options.add_argument("--start-maximized")

# inicia o navegador
navegador = webdriver.Chrome(options=options)

# 1. abre o Google
navegador.get("https://www.google.com")

# espera carregar
time.sleep(2)

# 2. localiza o campo de busca
campo_busca = navegador.find_element(By.NAME, "q")

# 3. digita o texto
campo_busca.send_keys("SPFC")

# 4. aperta Enter
campo_busca.send_keys(Keys.ENTER)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time

# (opcional) opções do Chrome
options = Options()
options.add_argument("--start-maximized")

# inicia o navegador
navegador = webdriver.Chrome(options=options)

# 1. abre o Google
navegador.get("https://www.google.com")

time.sleep(2)

sorte = navegador.find_element(By.XPATH,"/html/body/div[2]/div[4]/form/div[1]/div[1]/div[3]/center/input[2]")
sorte.click()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time

# (opcional) opções do Chrome
options = Options()
options.add_argument("--start-maximized")

# inicia o navegador
navegador = webdriver.Chrome(options=options)

navegador.get("https://chatgpt.com/")
navegador.find_element(
    By.XPATH,
    "//*[@id='stage-slideover-sidebar']/div/div[2]/nav/aside/a[1]/div[1]/div[2]/div"
).click()

# %%
navegador.get("https://chatgpt.com/")
elemento_lista = navegador.find_elements(
    By.XPATH,
    "//*[@id='stage-slideover-sidebar']/div/div[2]/nav/aside/a/div[1]/div[2]/div"
)

for elemento in elemento_lista:
    print(elemento.text)
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 navegador.get("https://chatgpt.com/")
#       2 elemento_lista = navegador.find_elements(
#       3     By.XPATH,
#       4     "//*[@id='stage-slideover-sidebar']/div/div[2]/nav/aside/a/div[1]/div[2]/div"
#       5 )
#       7 for elemento in elemento_lista:
#
# File c:\Users\negri\AppData\Local\Programs\Python\Python313\Lib\site-packages\selenium\webdriver\remote\webdriver.py:452, in WebDriver.get(self, url)
#     439 def get(self, url: str) -> None:
#     440     """Navigate the browser to the specified URL.
#     441
#     442     The method does not return until the page is fully loaded (i.e. the
#    (...)    450         `driver.get("https://example.com")`
#     451     """
# --> 452     self.execute(Command.GET, {"url": url})
#
# ...
