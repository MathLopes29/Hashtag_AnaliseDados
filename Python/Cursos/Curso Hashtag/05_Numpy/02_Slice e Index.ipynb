# %%
import numpy as np

teste = np.array([1,2,3,4,5], dtype=np.int32)
teste
# Out:
# array([1, 2, 3, 4, 5], dtype=int32)

# %%
teste.dtype
# Out:
# dtype('int32')

# %%
teste.shape
# Out:
# (5,)

# %% [markdown]
# Indexação e Slice (Pedaço)

# %%
print("indexação e slice")
print(teste[3]) # Indice 3
print(teste[1:2]) # Slice da posição 1 até a 2
# Out:
# indexação e slice
# 4
# [2]
