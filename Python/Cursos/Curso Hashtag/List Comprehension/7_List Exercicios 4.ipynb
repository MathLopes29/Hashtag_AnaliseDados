# %% [markdown]
# # Exercícios
#
# ## 1. Tamanho do Pedido de Compras
#
# Nesse exercício vamos avaliar o estoque de uma empresa. Vamos considerar que todos os produtos dessa empresa são comprados em lotes de 500 unidades.
#
# - Caso o estoque esteja abaixo de 1000 unidades, devemos fazer um pedido de 500 unidades.
# - Caso o estoque esteja abaixo de 200 unidades, devemos fazer um pedido de 1000 unidades.
#
# Defina o valor a ser pedido de cada produto para enviar ao time de compras.

# %%
estoque = [('BSA2199',396),('PPF5239',251),('BSA1212',989),('PPF2154',449),('BEB3410',241),('PPF8999',527),('EMB9591',601),('BSA2006',314),('EMB3604',469),('EMB2070',733),('PPF9018',339),('PPF1468',906),('BSA5819',291),('PPF8666',850),('BEB2983',353),('BEB5877',456),('PPF5008',963),('PPF3877',185),('PPF7321',163),('BSA8833',644),('PPF4980',421),('PPF3063',757),('BSA2089',271),('BSA8398',180),('EMB4622',515),('EMB9814',563),('PPF3784',229),('PPF2398',270),('BEB3211',181),('PPF8655',459),('PPF1874',799),('PPF8789',126),('PPF6324',375),('EMB9290',883),('BSA5516',555),('BSA8451',243),('BSA8213',423)]

# %%
pedidos = []

for cod, qtd in estoque:
    if qtd < 1000 :
        pedidos.append((cod, qtd+100))
    else: 
        pedidos.append((cod, qtd))

print(pedidos)

pedidos2 = pedidos.copy()

for cod, qtd in estoque:
    if qtd < 200:
        pedidos2.append((cod, qtd + 200))
    else:
        pedidos2.append((cod, qtd))

print(pedidos2)
# Out:
# [('BSA2199', 496), ('PPF5239', 351), ('BSA1212', 1089), ('PPF2154', 549), ('BEB3410', 341), ('PPF8999', 627), ('EMB9591', 701), ('BSA2006', 414), ('EMB3604', 569), ('EMB2070', 833), ('PPF9018', 439), ('PPF1468', 1006), ('BSA5819', 391), ('PPF8666', 950), ('BEB2983', 453), ('BEB5877', 556), ('PPF5008', 1063), ('PPF3877', 285), ('PPF7321', 263), ('BSA8833', 744), ('PPF4980', 521), ('PPF3063', 857), ('BSA2089', 371), ('BSA8398', 280), ('EMB4622', 615), ('EMB9814', 663), ('PPF3784', 329), ('PPF2398', 370), ('BEB3211', 281), ('PPF8655', 559), ('PPF1874', 899), ('PPF8789', 226), ('PPF6324', 475), ('EMB9290', 983), ('BSA5516', 655), ('BSA8451', 343), ('BSA8213', 523)]
# [('BSA2199', 496), ('PPF5239', 351), ('BSA1212', 1089), ('PPF2154', 549), ('BEB3410', 341), ('PPF8999', 627), ('EMB9591', 701), ('BSA2006', 414), ('EMB3604', 569), ('EMB2070', 833), ('PPF9018', 439), ('PPF1468', 1006), ('BSA5819', 391), ('PPF8666', 950), ('BEB2983', 453), ('BEB5877', 556), ('PPF5008', 1063), ('PPF3877', 285), ('PPF7321', 263), ('BSA8833', 744), ('PPF4980', 521), ('PPF3063', 857), ('BSA2089', 371), ('BSA8398', 280), ('EMB4622', 615), ('EMB9814', 663), ('PPF3784', 329), ('PPF2398', 370), ('BEB3211', 281), ('PPF8655', 559), ('PPF1874', 899), ('PPF8789', 226), ('PPF6324', 475), ('EMB9290', 983), ('BSA5516', 655), ('BSA8451', 343), ('BSA8213', 523), ('BSA2199', 396), ('PPF5239', 251), ('BSA1212', 989), ('PPF2154', 449), ('BEB3410', 241), ('PPF8999', 527), ('EMB9591', 601), ('BSA2006', 314), ('EMB3604', 469), ('EMB2070', 733), ('PPF9018', 339), ('PPF1468', 906), ('BSA5819', 291), ('PPF8666', 850), ('BEB2983', 353), ('BEB5877', 456), ('PPF5008', 963), ('PPF3877', 385), ('PPF7321', 363), ('BSA8833', 644), ('PPF4980', 421), ('PPF3063', 757), ('BSA2089', 271), ('BSA8398', 380), ('EMB4622', 515), ('EMB9814', 563), ('PPF3784', 229), ('PPF2398', 270), ('BEB3211', 381), ('PPF8655', 459), ('PPF1874', 799), ('PPF8789', 326), ('PPF6324', 375), ('EMB9290', 883), ('BSA5516', 555), ('BSA8451', 243), ('BSA8213', 423)]

# %%
pedidos = [(cod, qtd + 100) if qtd < 1000 else (cod, qtd) for cod, qtd in estoque]
print(pedidos)
# Out:
# [('BSA2199', 496), ('PPF5239', 351), ('BSA1212', 1089), ('PPF2154', 549), ('BEB3410', 341), ('PPF8999', 627), ('EMB9591', 701), ('BSA2006', 414), ('EMB3604', 569), ('EMB2070', 833), ('PPF9018', 439), ('PPF1468', 1006), ('BSA5819', 391), ('PPF8666', 950), ('BEB2983', 453), ('BEB5877', 556), ('PPF5008', 1063), ('PPF3877', 285), ('PPF7321', 263), ('BSA8833', 744), ('PPF4980', 521), ('PPF3063', 857), ('BSA2089', 371), ('BSA8398', 280), ('EMB4622', 615), ('EMB9814', 663), ('PPF3784', 329), ('PPF2398', 370), ('BEB3211', 281), ('PPF8655', 559), ('PPF1874', 899), ('PPF8789', 226), ('PPF6324', 475), ('EMB9290', 983), ('BSA5516', 655), ('BSA8451', 343), ('BSA8213', 523)]
