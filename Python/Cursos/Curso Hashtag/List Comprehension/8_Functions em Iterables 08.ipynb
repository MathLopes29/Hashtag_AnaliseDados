# %% [markdown]
# # List Comprehension não serve só para criar uma lista, serve para qualquer ação em iterable
#
# ### Exemplo:

# %% [markdown]
# - Vamos calcular quantos % das vendas o meu top 5 produtos representa das vendas totais

# %%
produtos = ['coca', 'pepsi', 'guarana', 'skol', 'brahma', 'agua', 'del valle', 'dolly', 'red bull', 'cachaça', 'vinho tinto', 'vodka', 'vinho branco', 'tequila', 'champagne', 'gin', 'guaracamp', 'matte', 'leite de castanha', 'leite', 'jurupinga', 'sprite', 'fanta']
vendas = [1200, 300, 800, 1500, 1900, 2750, 400, 20, 23, 70, 90, 80, 1100, 999, 900, 880, 870, 50, 1111, 120, 300, 450, 800]
top5 = []

for i in range(5):
    max_valor = max(vendas)

    indice = vendas.index(max_valor)
    top5.append((produtos[indice], max_valor))
    vendas[indice] = -1

print(top5)
# Out:
# [('agua', 2750), ('brahma', 1900), ('skol', 1500), ('coca', 1200), ('leite de castanha', 1111)]

# %% [markdown]
# - Fazendo por for

# %%
total_top5 = 0

for i, produto in enumerate(top5):
    if produto in top5:
        total_top5 += vendas[i]


print(total_top5)
print('Top 5 representou {:0.1%} das vendas'.format(total_top5/sum(vendas)))
# Out:
# 1097
# Top 5 representou 13.3% das vendas

# %% [markdown]
# - Fazendo por list comprehension

# %%
total_top5 = sum([vendas[i] for i, produto in enumerate(top5) if produto in top5])
print(total_top5)
print('Top 5 representou {:0.1%} das vendas'.format(total_top5/sum(vendas)))
# Out:
# 1097
# Top 5 representou 13.3% das vendas
