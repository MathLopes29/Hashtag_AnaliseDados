# %% [markdown]
# # Análise de dados com Pandas e Seaborn
#
# O Pandas é uma biblioteca Python de código aberto para análise de dados. Ela fornece ferramentas de análise de dados e estruturas de dados de alta performance e fáceis de usar. Já o Seaborn é uma biblioteca Python de visualização de dados baseada no matplotlib. Ela fornece uma interface de alto nível para desenhar gráficos estatísticos atraentes e informativos. Sua vantagem sobre o Matplotlib puro é que Seaborn fornece padrões de plotagem estatística que podem ser facilmente ativados com apenas alguns comandos.
#
# A base de dados utilizada aqui é de churn de clientes de uma empresa de telecomunicações. O churn é uma métrica que indica a taxa de evasão de clientes. Neste caso, o churn é definido como a perda de clientes para a concorrência ou por desinteresse em continuar com o serviço. O objetivo é analisar os dados e identificar os principais fatores que levam um cliente a cancelar o serviço.
#
# Temos o seguinte dicionário de dados:
#
# - `id_cliente`: identificador único do cliente
# - `genero`: gênero do cliente
# - `idoso`: indica se o cliente é idoso (mais de 65 anos) ou não
# - `tem_parceiro`: indica se o cliente tem parceiro ou não
# - `tem_dependentes`: indica se o cliente tem dependentes ou não
# - `meses_na_empresa`: quantidade de meses que o cliente permaneceu na empresa
# - `servico_telefone`: indica se o cliente tem serviço de telefone ou não
# - `multiplas_linhas`: indica se o cliente tem múltiplas linhas ou não
# - `servico_internet`: indica se o cliente tem serviço de internet (DSL ou fibra óptica) ou não
# - `servico_seguranca`: indica se o cliente tem serviço de segurança online ou não
# - `servico_backup`: indica se o cliente tem serviço de backup online ou não
# - `servico_protecao_equipamento`: indica se o cliente tem serviço de proteção do equipamento de conexão ou não
# - `servico_suporte_tecnico`: indica se o cliente tem serviço de suporte técnico prioritário ou não
# - `streaming_tv`: indica se o cliente tem serviço de streaming de TV ou não
# - `streaming_filmes`: indica se o cliente tem serviço de streaming de filmes ou não
# - `contrato`: tipo de contrato do cliente (mensal, anual ou dois anos)
# - `fatura_digital`: indica se o cliente recebe a fatura por e-mail ou não
# - `forma_pagamento`: forma de pagamento do cliente (cheque, boleto, transferência bancária ou cartão de crédito)
# - `valor_mensal`: valor mensal do serviço contratado
# - `total_gasto`: valor total gasto pelo cliente
# - `churn`: indica se o cliente cancelou o serviço no mês anterior ou não

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style='dark', palette='bright', context='notebook')

ARQUIVO_DADOS = 'churn_clientes.csv'

df_churn = pd.read_csv(ARQUIVO_DADOS)
df_churn = df_churn.drop(columns='id_cliente', axis=1)


colunas_numericas = df_churn.select_dtypes(include='number').columns
colunas_categoricas = df_churn.select_dtypes(exclude='number').columns
colunas_categoricas = colunas_categoricas.drop('churn')

df_churn.head()
# Out:
#       genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0   Feminino   Não          Sim             Não                 1
# 1  Masculino   Não          Não             Não                34
# 2  Masculino   Não          Não             Não                 2
# 3  Masculino   Não          Não             Não                45
# 4   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  \
# 0              Não              Não              DSL               Não
# 1              Sim              Não              DSL               Sim
# 2              Sim              Não              DSL               Sim
# 3              Não              Não              DSL               Sim
# 4              Sim              Não     Fibra optica               Não
#
#   servico_backup servico_protecao_equipamento servico_suporte_tecnico  \
# 0            Sim                          Não                     Não
# 1            Não                          Sim                     Não
# 2            Sim                          Não                     Não
# 3            Não                          Sim                     Sim
# 4            Não                          Não                     Não
#
#   streaming_tv streaming_filmes contrato fatura_digital forma_pagamento  \
# 0          Não              Não   Mensal            Sim          Boleto
# 1          Não              Não    Anual            Não          Cheque
# 2          Não              Não   Mensal            Sim          Cheque
# 3          Não              Não    Anual            Não   Transferencia
# 4          Não              Não   Mensal            Sim          Boleto
#
#    valor_mensal  total_gasto churn
# 0         29.85        29.85   Não
# 1         56.95      1889.50   Não
# 2         53.85       108.15   Sim
# 3         42.30      1840.75   Não
# 4         70.70       151.65   Sim

# %% [markdown]
# ## Variáveis categóricas

# %% [markdown]
# ## Correlação entre variáveis

# %% [markdown]
# A correlação é uma medida estatística que indica a relação entre duas variáveis. A correlação pode ser positiva, negativa ou neutra. Quando a correlação é positiva, significa que as variáveis possuem uma relação direta. Quando uma variável aumenta, a outra também aumenta. Quando a correlação é negativa, significa que as variáveis possuem uma relação inversa. Quando uma variável aumenta, a outra diminui. Quando a correlação é neutra, significa que as variáveis não possuem relação entre si.
#
# Os valores da correlação variam entre -1 e 1. Quando a correlação é -1, significa que as variáveis possuem uma correlação negativa perfeita. Quando a correlação é 1, significa que as variáveis possuem uma correlação positiva perfeita. Quando a correlação é 0, significa que as variáveis não possuem correlação. Quanto mais próximo de 1 ou -1, mais forte é a correlação. Quanto mais próximo de 0, mais fraca é a correlação.

# %%
df_churn.corr(numeric_only=True)
# Out:
#                   meses_na_empresa  valor_mensal  total_gasto
# meses_na_empresa          1.000000      0.247900     0.825464
# valor_mensal              0.247900      1.000000     0.650864
# total_gasto               0.825464      0.650864     1.000000

# %%
df_churn['churn'].nunique()
# Out:
# 2

# %%
df_churn['churn'] = df_churn['churn'].replace({'Sim':1,'Não':0})
df_churn.head()
# Out:
# C:\Users\matheus.lourenco\AppData\Local\Temp\ipykernel_18408\3376933223.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_churn['churn'] = df_churn['churn'].replace({'Sim':1,'Não':0})
#       genero idoso tem_parceiro tem_dependentes  meses_na_empresa  \
# 0   Feminino   Não          Sim             Não                 1
# 1  Masculino   Não          Não             Não                34
# 2  Masculino   Não          Não             Não                 2
# 3  Masculino   Não          Não             Não                45
# 4   Feminino   Não          Não             Não                 2
#
#   servico_telefone multiplas_linhas servico_internet servico_seguranca  \
# 0              Não              Não              DSL               Não
# 1              Sim              Não              DSL               Sim
# 2              Sim              Não              DSL               Sim
# 3              Não              Não              DSL               Sim
# 4              Sim              Não     Fibra optica               Não
#
#   servico_backup servico_protecao_equipamento servico_suporte_tecnico  \
# 0            Sim                          Não                     Não
# 1            Não                          Sim                     Não
# 2            Sim                          Não                     Não
# 3            Não                          Sim                     Sim
# 4            Não                          Não                     Não
#
#   streaming_tv streaming_filmes contrato fatura_digital forma_pagamento  \
# 0          Não              Não   Mensal            Sim          Boleto
# 1          Não              Não    Anual            Não          Cheque
# 2          Não              Não   Mensal            Sim          Cheque
# 3          Não              Não    Anual            Não   Transferencia
# 4          Não              Não   Mensal            Sim          Boleto
#
#    valor_mensal  total_gasto  churn
# 0         29.85        29.85      0
# 1         56.95      1889.50      0
# 2         53.85       108.15      1
# 3         42.30      1840.75      0
# 4         70.70       151.65      1

# %%
df_dumies = pd.get_dummies(df_churn)
df_dumies.head()
# Out:
#    meses_na_empresa  valor_mensal  total_gasto  churn  genero_Feminino  \
# 0                 1         29.85        29.85      0             True
# 1                34         56.95      1889.50      0            False
# 2                 2         53.85       108.15      1            False
# 3                45         42.30      1840.75      0            False
# 4                 2         70.70       151.65      1             True
#
#    genero_Masculino  idoso_Não  idoso_Sim  tem_parceiro_Não  tem_parceiro_Sim  \
# 0             False       True      False             False              True
# 1              True       True      False              True             False
# 2              True       True      False              True             False
# 3              True       True      False              True             False
# 4             False       True      False              True             False
#
#    ...  streaming_filmes_Sim  contrato_Anual  contrato_Bianual  \
# 0  ...                 False           False             False
# 1  ...                 False            True             False
# 2  ...                 False           False             False
# 3  ...                 False            True             False
# 4  ...                 False           False             False
#
#    contrato_Mensal  fatura_digital_Não  fatura_digital_Sim  \
# 0             True               False                True
# 1            False                True               False
# 2             True               False                True
# 3            False                True               False
# 4             True               False                True
#
#    forma_pagamento_Boleto  forma_pagamento_Cartao de credito  \
# 0                    True                              False
# 1                   False                              False
# 2                   False                              False
# 3                   False                              False
# 4                    True                              False
#
#    forma_pagamento_Cheque  forma_pagamento_Transferencia
# 0                   False                          False
# 1                    True                          False
# 2                    True                          False
# 3                   False                           True
# 4                   False                          False
#
# [5 rows x 40 columns]

# %%
churn_corr = df_dumies.corr()['churn'].sort_values(ascending=False)
print(churn_corr)
# Out:
# churn                                1.000000
# contrato_Mensal                      0.405103
# servico_internet_Fibra optica        0.308020
# forma_pagamento_Boleto               0.301919
# valor_mensal                         0.193356
# fatura_digital_Sim                   0.191825
# servico_seguranca_Não                0.171226
# servico_suporte_tecnico_Não          0.164674
# tem_dependentes_Não                  0.164221
# idoso_Sim                            0.150889
# tem_parceiro_Não                     0.150448
# servico_backup_Não                   0.082255
# servico_protecao_equipamento_Não     0.066160
# streaming_tv_Sim                     0.063228
# streaming_filmes_Sim                 0.061382
# multiplas_linhas_Sim                 0.040102
# servico_telefone_Sim                 0.011942
# genero_Feminino                      0.008612
# genero_Masculino                    -0.008612
# servico_telefone_Não                -0.011942
# multiplas_linhas_Não                -0.040102
# streaming_filmes_Não                -0.061382
# streaming_tv_Não                    -0.063228
# servico_protecao_equipamento_Sim    -0.066160
# servico_backup_Sim                  -0.082255
# forma_pagamento_Cheque              -0.091683
# forma_pagamento_Transferencia       -0.117937
# servico_internet_DSL                -0.124214
# forma_pagamento_Cartao de credito   -0.134302
# tem_parceiro_Sim                    -0.150448
# idoso_Não                           -0.150889
# tem_dependentes_Sim                 -0.164221
# servico_suporte_tecnico_Sim         -0.164674
# servico_seguranca_Sim               -0.171226
# contrato_Anual                      -0.177820
# fatura_digital_Não                  -0.191825
# total_gasto                         -0.199037
# servico_internet_Não                -0.227890
# contrato_Bianual                    -0.302253
# meses_na_empresa                    -0.352229
# Name: churn, dtype: float64

# %%
churn_corr[1:].plot(kind='bar', figsize=(10,5));

# %%
fig, ax = plt.subplots(figsize=(16,6))

b = sns.barplot(x= churn_corr[1:].index, y=churn_corr[1:].values, palette='coolwarm', ax=ax)
b.tick_params(rotation=90)
plt.show()
# Out:
# C:\Users\matheus.lourenco\AppData\Local\Temp\ipykernel_18408\2597257307.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   b = sns.barplot(x= churn_corr[1:].index, y=churn_corr[1:].values, palette='coolwarm', ax=ax)

# %%
df_dumies.corr().style.format(precision=2).background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_62b67_row0_col0, #T_62b67_row1_col1, #T_62b67_row2_col2, #T_62b67_row3_col3, #T_62b67_row4_col4, #T_62b67_row5_col5, #T_62b67_row6_col6, #T_62b67_row7_col7, #T_62b67_row8_col8, #T_62b67_row9_col9, #T_62b67_row10_col10, #T_62b67_row11_col11, #T_62b67_row12_col12, #T_62b67_row13_col13, #T_62b67_row14_col14, #T_62b67_row15_col15, #T_62b67_row16_col16, #T_62b67_row17_col17, #T_62b67_row18_col18, #T_62b67_row19_col19, #T_62b67_row20_col20, #T_62b67_row21_col21, #T_62b67_row22_col22, #T_62b67_row23_col23, #T_62b67_row24_col24, #T_62b67_row25_col25, #T_62b67_row26_col26, #T_62b67_row27_col27, #T_62b67_row28_col28, #T_62b67_row29_col29, #T_62b67_row30_col30, #T_62b67_row31_col31, #T_62b67_row32_col32, #T_62b67_row33_col33, #T_62b67_row34_col34, #T_62b67_row35_col35, #T_62b67_row36_col36, #T_62b67_row37_col37, #T_62b67_row38_col38, #T_62b67_row39_col39 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_62b67_row0_col1, #T_62b67_row6_col14, #T_62b67_row7_col15, #T_62b67_row8_col14, #T_62b67_row8_col19, #T_62b67_row8_col21, #T_62b67_row9_col15, #T_62b67_row9_col20, #T_62b67_row9_col22, #T_62b67_row13_col1, #T_62b67_row14_col6, #T_62b67_row14_col8, #T_62b67_row15_col7, #T_62b67_row15_col9, #T_62b67_row16_col24, #T_62b67_row19_col8, #T_62b67_row20_col9, #T_62b67_row21_col8, #T_62b67_row22_col9, #T_62b67_row32_col34, #T_62b67_row36_col28 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_62b67_row0_col2 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_62b67_row0_col3, #T_62b67_row0_col33, #T_62b67_row1_col18, #T_62b67_row4_col5, #T_62b67_row5_col4, #T_62b67_row6_col7, #T_62b67_row7_col6, #T_62b67_row8_col9, #T_62b67_row9_col8, #T_62b67_row10_col11, #T_62b67_row11_col10, #T_62b67_row12_col13, #T_62b67_row13_col12, #T_62b67_row14_col15, #T_62b67_row15_col14, #T_62b67_row16_col17, #T_62b67_row17_col16, #T_62b67_row18_col1, #T_62b67_row19_col20, #T_62b67_row20_col19, #T_62b67_row21_col22, #T_62b67_row22_col21, #T_62b67_row23_col2, #T_62b67_row23_col24, #T_62b67_row24_col23, #T_62b67_row25_col26, #T_62b67_row26_col25, #T_62b67_row27_col28, #T_62b67_row28_col27, #T_62b67_row29_col2, #T_62b67_row29_col30, #T_62b67_row30_col29, #T_62b67_row33_col0, #T_62b67_row33_col31, #T_62b67_row33_col32, #T_62b67_row34_col35, #T_62b67_row35_col34, #T_62b67_row36_col37, #T_62b67_row36_col38, #T_62b67_row36_col39, #T_62b67_row38_col36 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_62b67_row0_col4, #T_62b67_row0_col34, #T_62b67_row2_col5, #T_62b67_row3_col36, #T_62b67_row4_col6, #T_62b67_row4_col8, #T_62b67_row4_col12, #T_62b67_row4_col23, #T_62b67_row5_col7, #T_62b67_row5_col9, #T_62b67_row5_col13, #T_62b67_row5_col24, #T_62b67_row6_col4, #T_62b67_row7_col5, #T_62b67_row8_col4, #T_62b67_row9_col5, #T_62b67_row10_col1, #T_62b67_row10_col12, #T_62b67_row11_col13, #T_62b67_row12_col4, #T_62b67_row12_col10, #T_62b67_row13_col5, #T_62b67_row13_col11, #T_62b67_row16_col4, #T_62b67_row16_col9, #T_62b67_row17_col8, #T_62b67_row18_col4, #T_62b67_row18_col8, #T_62b67_row19_col34, #T_62b67_row20_col35, #T_62b67_row23_col4, #T_62b67_row24_col5, #T_62b67_row24_col17, #T_62b67_row31_col13, #T_62b67_row31_col15, #T_62b67_row32_col5, #T_62b67_row32_col12, #T_62b67_row33_col5, #T_62b67_row33_col13, #T_62b67_row34_col19, #T_62b67_row35_col20, #T_62b67_row36_col4, #T_62b67_row36_col12, #T_62b67_row36_col22, #T_62b67_row36_col24, #T_62b67_row37_col4, #T_62b67_row37_col13, #T_62b67_row38_col13, #T_62b67_row39_col12 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_62b67_row0_col5, #T_62b67_row0_col35, #T_62b67_row2_col4, #T_62b67_row4_col7, #T_62b67_row4_col9, #T_62b67_row4_col13, #T_62b67_row4_col24, #T_62b67_row5_col6, #T_62b67_row5_col8, #T_62b67_row5_col12, #T_62b67_row5_col23, #T_62b67_row6_col5, #T_62b67_row7_col4, #T_62b67_row8_col5, #T_62b67_row9_col4, #T_62b67_row10_col13, #T_62b67_row11_col12, #T_62b67_row12_col5, #T_62b67_row12_col11, #T_62b67_row13_col4, #T_62b67_row13_col10, #T_62b67_row16_col5, #T_62b67_row16_col8, #T_62b67_row17_col9, #T_62b67_row18_col5, #T_62b67_row18_col9, #T_62b67_row19_col35, #T_62b67_row20_col32, #T_62b67_row20_col34, #T_62b67_row23_col5, #T_62b67_row24_col4, #T_62b67_row31_col12, #T_62b67_row31_col14, #T_62b67_row32_col4, #T_62b67_row32_col13, #T_62b67_row33_col4, #T_62b67_row33_col12, #T_62b67_row34_col20, #T_62b67_row35_col19, #T_62b67_row36_col5, #T_62b67_row36_col13, #T_62b67_row36_col21, #T_62b67_row36_col23, #T_62b67_row37_col5, #T_62b67_row37_col12, #T_62b67_row38_col12, #T_62b67_row39_col13 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_62b67_row0_col6, #T_62b67_row0_col31, #T_62b67_row4_col19, #T_62b67_row5_col20, #T_62b67_row6_col9, #T_62b67_row7_col8, #T_62b67_row8_col7, #T_62b67_row8_col13, #T_62b67_row9_col6, #T_62b67_row9_col12, #T_62b67_row10_col17, #T_62b67_row10_col27, #T_62b67_row11_col0, #T_62b67_row11_col28, #T_62b67_row12_col9, #T_62b67_row12_col27, #T_62b67_row12_col35, #T_62b67_row13_col8, #T_62b67_row13_col28, #T_62b67_row13_col34, #T_62b67_row16_col27, #T_62b67_row17_col26, #T_62b67_row19_col4, #T_62b67_row20_col5, #T_62b67_row21_col33, #T_62b67_row22_col17, #T_62b67_row27_col10, #T_62b67_row27_col12, #T_62b67_row28_col11, #T_62b67_row28_col13, #T_62b67_row34_col13, #T_62b67_row35_col12, #T_62b67_row37_col32, #T_62b67_row39_col5, #T_62b67_row39_col7, #T_62b67_row39_col35 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_62b67_row0_col7, #T_62b67_row4_col20, #T_62b67_row5_col19, #T_62b67_row6_col8, #T_62b67_row7_col9, #T_62b67_row8_col6, #T_62b67_row8_col12, #T_62b67_row9_col7, #T_62b67_row9_col13, #T_62b67_row10_col28, #T_62b67_row11_col27, #T_62b67_row11_col32, #T_62b67_row12_col8, #T_62b67_row12_col28, #T_62b67_row12_col34, #T_62b67_row13_col9, #T_62b67_row13_col27, #T_62b67_row13_col35, #T_62b67_row16_col28, #T_62b67_row17_col25, #T_62b67_row18_col38, #T_62b67_row19_col5, #T_62b67_row20_col4, #T_62b67_row27_col11, #T_62b67_row27_col13, #T_62b67_row28_col10, #T_62b67_row28_col12, #T_62b67_row34_col12, #T_62b67_row35_col13, #T_62b67_row39_col4, #T_62b67_row39_col6, #T_62b67_row39_col34 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_62b67_row0_col8, #T_62b67_row7_col32, #T_62b67_row8_col31, #T_62b67_row11_col39, #T_62b67_row16_col2, #T_62b67_row16_col37, #T_62b67_row16_col38, #T_62b67_row18_col22, #T_62b67_row18_col24, #T_62b67_row21_col31, #T_62b67_row23_col3, #T_62b67_row30_col39, #T_62b67_row33_col18 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_62b67_row0_col9, #T_62b67_row18_col21, #T_62b67_row18_col23 {
#   background-color: #f7b093;
#   color: #000000;
# }
# #T_62b67_row0_col10, #T_62b67_row2_col34, #T_62b67_row6_col35, #T_62b67_row7_col34, #T_62b67_row14_col35, #T_62b67_row15_col34, #T_62b67_row16_col21, #T_62b67_row31_col16, #T_62b67_row34_col7, #T_62b67_row34_col15, #T_62b67_row35_col6, #T_62b67_row35_col14 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_62b67_row0_col11, #T_62b67_row2_col35, #T_62b67_row3_col17, #T_62b67_row6_col34, #T_62b67_row7_col35, #T_62b67_row14_col34, #T_62b67_row15_col35, #T_62b67_row16_col22, #T_62b67_row17_col2, #T_62b67_row26_col16, #T_62b67_row34_col6, #T_62b67_row34_col14, #T_62b67_row35_col7, #T_62b67_row35_col15 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_62b67_row0_col12, #T_62b67_row1_col5, #T_62b67_row3_col5, #T_62b67_row3_col12, #T_62b67_row4_col11, #T_62b67_row4_col14, #T_62b67_row4_col21, #T_62b67_row4_col25, #T_62b67_row4_col27, #T_62b67_row4_col29, #T_62b67_row4_col34, #T_62b67_row5_col10, #T_62b67_row5_col15, #T_62b67_row5_col22, #T_62b67_row5_col26, #T_62b67_row5_col28, #T_62b67_row5_col30, #T_62b67_row5_col35, #T_62b67_row6_col13, #T_62b67_row7_col12, #T_62b67_row8_col34, #T_62b67_row9_col35, #T_62b67_row10_col5, #T_62b67_row10_col24, #T_62b67_row11_col4, #T_62b67_row11_col23, #T_62b67_row12_col7, #T_62b67_row13_col6, #T_62b67_row14_col4, #T_62b67_row15_col5, #T_62b67_row17_col5, #T_62b67_row21_col4, #T_62b67_row22_col5, #T_62b67_row23_col11, #T_62b67_row24_col10, #T_62b67_row25_col4, #T_62b67_row26_col5, #T
